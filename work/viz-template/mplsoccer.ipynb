# %% [markdown]
# ## mplsoccer

# %%
from mplsoccer.quiver import arrows
import matplotlib.pyplot as plt
from mplsoccer import Pitch

# %% [markdown]
# ### Arrow

# %%
fig, ax = plt.subplots()
arrows([0.1, 0.4], [0.1, 0.5], [0.9, 0.4], [0.8, 0.8], ax=ax)
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> pitch.arrows(20, 20, 45, 80, ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch(line_zorder=2, pitch_color='black')
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=100)
>>> y = np.random.uniform(low=0, high=80, size=100)
>>> stats = pitch.bin_statistic(x, y)
>>> pitch.heatmap(stats, edgecolors='black', cmap='hot', ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch(line_zorder=2, pitch_color='black')
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=100)
>>> y = np.random.uniform(low=0, high=80, size=100)
>>> stats = pitch.bin_statistic_positional(x, y)
>>> pitch.heatmap_positional(stats, edgecolors='black', cmap='hot', ax=ax)
# Out:
# [<matplotlib.collections.QuadMesh at 0x7fab64cec370>,
#  <matplotlib.collections.QuadMesh at 0x7fab64cec550>,
#  <matplotlib.collections.QuadMesh at 0x7fab64ec2580>,
#  <matplotlib.collections.QuadMesh at 0x7fab64e64df0>,
#  <matplotlib.collections.QuadMesh at 0x7fab64cd1790>]

# %%
>>> from mplsoccer import Pitch
>>> pitch = Pitch()
>>> pitch.calculate_angle_and_distance(0, 40, 30, 20, degrees=True)
# Out:
# (array([326.30993247]), array([36.05551275]))

# %%
>>> from mplsoccer import Pitch
>>> pitch = Pitch()
>>> grid_width, grid_height = pitch.calculate_grid_dimensions(figwidth=16, figheight=9,                                                                       nrows=1, ncols=1,                                                                       max_grid=1,  space=0)

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=11)
>>> y = np.random.uniform(low=0, high=80, size=11)
>>> hull = pitch.convexhull(x, y)
>>> poly = pitch.polygon(hull, ax=ax, facecolor='cornflowerblue', alpha=0.3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ab7c5eb4e3f2> in <module>
#       5 x = np.random.uniform(low=0, high=120, size=11)
#       6 y = np.random.uniform(low=0, high=80, size=11)
# ----> 7 hull = pitch.convexhull(x, y)
#       8 poly = pitch.polygon(hull, ax=ax, facecolor='cornflowerblue', alpha=0.3)
#
# AttributeError: 'Pitch' object has no attribute 'convexhull'

# %%
>>> from mplsoccer import Pitch
>>> from mplsoccer.statsbomb import read_event, EVENT_SLUG
>>> df = read_event(f'{EVENT_SLUG}/7478.json', related_event_df=False,                             shot_freeze_frame_df=False, tactics_lineup_df=False)['event']
>>> team1, team2 = df.team_name.unique()
>>> mask_team1 = (df.type_name == 'Pass') & (df.team_name == team1)
>>> df = df[mask_team1].copy()
>>> pitch = Pitch(line_zorder=2)
>>> fig, ax = pitch.draw()
>>> bs_heatmap = pitch.bin_statistic(df.x, df.y, statistic='count', bins=(6, 4))
>>> hm = pitch.heatmap(bs_heatmap, ax=ax, cmap='Blues')
>>> fm = pitch.flow(df.x, df.y, df.end_x, df.end_y, color='black', arrow_type='same',                             arrow_length=6, bins=(6, 4), headwidth=2, headlength=2,                             headaxislength=2, ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> pitch.goal_angle(100, 30, alpha=0.5, color='red', ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> pitch = Pitch()
>>> fig, axs = pitch.grid(nrows=3, ncols=3, grid_height=0.7, figheight=14)

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch(line_zorder=2, pitch_color='black')
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=100)
>>> y = np.random.uniform(low=0, high=80, size=100)
>>> stats = pitch.bin_statistic(x, y)
>>> pitch.heatmap(stats, edgecolors='black', cmap='hot', ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch(line_zorder=2, pitch_color='black')
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=100)
>>> y = np.random.uniform(low=0, high=80, size=100)
>>> stats = pitch.bin_statistic_positional(x, y)
>>> pitch.heatmap_positional(stats, edgecolors='black', cmap='hot', ax=ax)
# Out:
# [<matplotlib.collections.QuadMesh at 0x7fab60f73be0>,
#  <matplotlib.collections.QuadMesh at 0x7fab60f73f70>,
#  <matplotlib.collections.QuadMesh at 0x7fab60efd340>,
#  <matplotlib.collections.QuadMesh at 0x7fab60efd6d0>,
#  <matplotlib.collections.QuadMesh at 0x7fab60efda60>]

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch(line_zorder=2)
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=100)
>>> y = np.random.uniform(low=0, high=80, size=100)
>>> pitch.hexbin(x, y, edgecolors='black', gridsize=(11, 5), cmap='Reds', ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> import seaborn as sns
>>> pitch = Pitch()
>>> fig, axs = pitch.jointgrid(ax_left=False, ax_right=False,                                        ax_bottom=False, ax_top=True)
>>> x = np.random.uniform(low=0, high=120, size=100)
>>> sns.kdeplot(x=x, ax=axs['top'], shade=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-05344af864f4> in <module>
#       5 fig, axs = pitch.jointgrid(ax_left=False, ax_right=False,                                        ax_bottom=False, ax_top=True)
#       6 x = np.random.uniform(low=0, high=120, size=100)
# ----> 7 sns.kdeplot(x=x, ax=axs['top'], shade=True)
#
# TypeError: kdeplot() missing 1 required positional argument: 'data'

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch(line_zorder=2)
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=100)
>>> y = np.random.uniform(low=0, high=80, size=100)
>>> pitch.kdeplot(x, y, cmap='Reds', shade=True, levels=100, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-fcc9f4814bb4> in <module>
#       5 x = np.random.uniform(low=0, high=120, size=100)
#       6 y = np.random.uniform(low=0, high=80, size=100)
# ----> 7 pitch.kdeplot(x, y, cmap='Reds', shade=True, levels=100, ax=ax)
#
# /opt/anaconda3/lib/python3.8/site-packages/mplsoccer/_pitch_plot.py in kdeplot(self, x, y, ax, **kwargs)
#     173         x, y = self._reverse_if_vertical(x, y)
#     174
# --> 175         contour_plot = sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
#     176         return contour_plot
#     177
#
# TypeError: kdeplot() missing 1 required positional argument: 'data'

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> import matplotlib.patheffects as path_effects
>>> pitch = Pitch(line_zorder=2, pitch_color='black')
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=100)
>>> y = np.random.uniform(low=0, high=80, size=100)
>>> stats = pitch.bin_statistic(x, y)
>>> pitch.heatmap(stats, edgecolors='black', cmap='hot', ax=ax)
>>> stats['statistic'] = stats['statistic'].astype(int)
>>> path_eff = [path_effects.Stroke(linewidth=0.5, foreground='#22312b')]
>>> text = pitch.label_heatmap(stats, color='white', ax=ax, fontsize=20, ha='center', va='center', path_effects=path_eff)

# %%
>>> from mplsoccer import Pitch
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> pitch.lines(20, 20, 45, 80, comet=True, transparent=True, ax=ax)
>>> from mplsoccer.linecollection import lines
>>> import matplotlib.pyplot as plt
>>> fig, ax = plt.subplots()
>>> lines([0.1, 0.4], [0.1, 0.5], [0.9, 0.4], [0.8, 0.8], ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> pitch.plot([30, 35, 20], [30, 19, 40], ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch(label=True, axis=True)
>>> fig, ax = pitch.draw()
>>> shape1 = np.array([[50, 2], [80, 30], [40, 30], [40, 20]])
>>> shape2 = np.array([[70, 70], [60, 50], [40, 40]])
>>> verts = [shape1, shape2]
>>> pitch.polygon(verts, color='red', alpha=0.3, ax=ax)

# %%
>>> from mplsoccer import Pitch
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> pitch.scatter(30, 30, ax=ax)
>>> from mplsoccer import Pitch
>>> from mplsoccer import arrowhead_marker
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> pitch.scatter(30, 30, rotation_degrees=45, marker=arrowhead_marker, ax=ax)
>>> from mplsoccer import Pitch
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> pitch.scatter(30, 30, marker='football', ax=ax)
# Out:
# (<matplotlib.collections.PathCollection at 0x7fab609a9100>,
#  <matplotlib.collections.PathCollection at 0x7fab609a94f0>)

# %%
>>> from mplsoccer import Pitch
>>> import numpy as np
>>> pitch = Pitch()
>>> fig, ax = pitch.draw()
>>> x = np.random.uniform(low=0, high=120, size=22)
>>> y = np.random.uniform(low=0, high=80, size=22)
>>> teams = np.array([0] * 11 + [1] * 11)
>>> pitch.scatter(x[teams == 0], y[teams == 0], color='red', ax=ax)
>>> pitch.scatter(x[teams == 1], y[teams == 1], color='blue', ax=ax)
>>> team1, team2 = pitch.voronoi(x, y, teams)
>>> team1_poly = pitch.polygon(team1, ax=ax, color='blue', alpha=0.3)
>>> team2_poly = pitch.polygon(team2, ax=ax, color='red', alpha=0.3)
