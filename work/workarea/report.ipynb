# %%
import pandas as pd
import numpy as np
import seaborn as sns
from PIL import Image
from imageio import imread
from skimage.transform import resize
import math
from math import pi
import scipy.stats
from selenium import webdriver
import warnings

import matplotlib as mpl
from matplotlib import colors
import matplotlib.patches as patches
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.colors import to_rgba
import matplotlib.pyplot as plt
from matplotlib.markers import MarkerStyle
import matplotlib.image as mpimg
import matplotlib.image as image
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
from matplotlib.projections import get_projection_class
from matplotlib.projections import get_projection_class
import matplotlib.cm as cm

from highlight_text import htext

from mplsoccer import Pitch, add_image, VerticalPitch
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

warnings.filterwarnings('ignore')

faceColor = '#ffffff'
basicColor = '#131313'
oneColor = '#7E13D6'
otherColor = '#D61313'

mpl.rcParams['xtick.color'] = '#131313'
mpl.rcParams['ytick.color'] = '#131313'
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['xtick.labelsize'] = 12

# %%
# eam = 'barcelona'
# pk = '206d90db'
# # url = f'https://fbref.com/en/squads/{pk}/{team}-Stats'
# # url = 'https://fbref.com/en/squads/e2d8892c/Paris-Saint-Germain-Stats'
# url = 'https://fbref.com/en/squads/db3b9613/Atletico-Madrid-Stats'
# html = requests.get(url)
# soup = BeautifulSoup(html.content,'html.parser')
# table = soup.find_all('table')
# tbody = table[0].find('tbody')
# # table = BeautifulSoup(table[0], "lxml").find("table")
# df = pd.read_html(table[1].prettify(), flavor='bs4')[0]
# df.to_csv(f'/work/assets/fbref/team/atletico-madrid/team/season.csv')
# df2.columns

# %%
# df = pd.read_csv('/work/assets/fbref/teamStats/atletico-madrid/team/season.csv')
df = pd.read_csv('/work/assets/fbref/teamStats/barcelona/fixture2122.csv')


df = df.dropna(subset=['xG'])

df['gSMA'] = df['GF'].rolling(window=3).mean()
df['gaSMA'] = df['GA'].rolling(window=3).mean()
df['xgSMA'] = df['xG'].rolling(window=3).mean()
df['xgaSMA'] = df['xGA'].rolling(window=3).mean()

df = df.reset_index(drop=True)

# df2 = df2.dropna(subset=['xG'])

# df2['gSMA'] = df2['GF'].rolling(window=3).mean()
# df2['gaSMA'] = df2['GA'].rolling(window=3).mean()
# df2['xgSMA'] = df2['xG'].rolling(window=3).mean()
# df2['xgaSMA'] = df2['xGA'].rolling(window=3).mean()

# df2 = df2.reset_index(drop=True)

fig,ax = plt.subplots(figsize=(12,8),facecolor="#131313")
ax.set_facecolor("#131313")
ax.set_zorder(1)
# ax.set_xticks(np.arange(25))
# ax.set_xticklabels(np.arange(25),color="white",fontsize=12, fontweight="bold")
# ax.tick_params(colors="w", length=15, left=True, bottom=True, labelbottom=True, labelleft=True)
ax.set_xlabel("game",color="w")
ax.set_ylabel("psxG-GA( rolling mean )",color="w")

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_color("w")
ax.spines['right'].set_visible(False)

# ax.grid(which='both',color='#dedede')
# plt.xticks(np.linspace(0,50,10),['Sep','Oct','Nov','Dec','Jan','Feb','Mar','Apr'])
# plt.yticks(np.linspace(0,100,6),['','0%','20%','40%','60%','80%'])

# ax.plot(df['xgSMA'],marker='o',markersize=10,color=otherColor,alpha=.5)
ax.plot(df['GF'],marker='o',markersize=10,color=otherColor)

# ax.plot(df2['xgSMA'],marker='o',markersize=10,color=oneColor)
# ax.plot(df2['gSMA'],marker='o',markersize=10,color=oneColor,alpha=.2)

# ax.text(x=1.5,y=3.4,s='Atletico\'s xG is Going Down!?',fontsize=32,fontweight='bold',fontname='cmss10')

# htext.fig_text(
#     x=.15,y=.9,
#     s='Atletico\'s <Goals> and <xG> three match average',
#     fontsize=18,
#     color=basicColor,
#     highlight_colors=[otherColor, '#E57D84'],
# #     highlight_weights = 'bold',
#     fontname='cmss10',
# #     fontweight='bold'
# )

# %%
df = pd.read_csv('/work/assets/fbref/team/atletico-madrid/team/season.csv')
df2 = pd.read_csv('/work/assets/fbref/team/barcelona/team/season.csv')
df3 = pd.read_csv('/work/assets/fbref/report/griezmann_summary.csv')


df = df.dropna(subset=['xG'])

df['gSMA'] = df['GF'].rolling(window=3).mean()
df['gaSMA'] = df['GA'].rolling(window=3).mean()
df['xgSMA'] = df['xG'].rolling(window=3).mean()
df['xgaSMA'] = df['xGA'].rolling(window=3).mean()

df = df.reset_index(drop=True)

df2 = df2.dropna(subset=['xG'])

df2['gSMA'] = df2['GF'].rolling(window=3).mean()
df2['gaSMA'] = df2['GA'].rolling(window=3).mean()
df2['xgSMA'] = df2['xG'].rolling(window=3).mean()
df2['xgaSMA'] = df2['xGA'].rolling(window=3).mean()

df2 = df2.reset_index(drop=True)

fig,ax = plt.subplots(figsize=(12,8),facecolor=faceColor)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.grid(which='both',color='#dedede')
plt.xticks(np.linspace(0,50,10),['Sep','Oct','Nov','Dec','Jan','Feb','Mar','Apr'])
# plt.yticks(np.linspace(0,100,6),['','0%','20%','40%','60%','80%'])


ax.plot(df2['xgSMA'],marker='o',markersize=10,color=oneColor)
ax.plot(df2['gSMA'],marker='o',markersize=10,color=oneColor,alpha=.2)

ax.text(x=1.5,y=4.1,s='Barcelona\'s xG is Going Up!?',fontsize=32,fontweight='bold',fontname='cmss10')

htext.fig_text(
    x=.15,y=.89,
    s='Barcelona\'s <Goals> and <xG> three match average',
    fontsize=18,
    color=basicColor,
    highlight_colors=[oneColor, '#a0c4ff'],
    highlight_weights = 'bold',
    fontname='cmss10',
    fontweight='bold'
)
# Out:
# [[Text(0.15, 0.9160416666666666, "Barcelona's "),
#   Text(0.25633680555555555, 0.9160416666666666, 'Goals'),
#   Text(0.30350115740740735, 0.9160416666666666, ' and '),
#   Text(0.3489293981481481, 0.9160416666666666, 'xG'),
#   Text(0.3723668981481481, 0.9160416666666666, ' three match average')]]

# %%
df = pd.read_csv('/work/assets/fbref/report/felix_summary.csv')
df2 = pd.read_csv('/work/assets/fbref/report/correasummary.csv')


df = df.dropna(subset=['Gls_Performance'])
df = df.iloc[:-1,:]

df['gSMA'] = df['Gls_Performance'].rolling(window=3).mean()
df['xgSMA'] = df['xG_Expected'].rolling(window=3).mean()

df = df.dropna(subset=['xgSMA'])

df = df.reset_index(drop=True)

df2 = df2.dropna(subset=['Gls_Performance'])
df2 = df2.iloc[:-1,:]

df2['gSMA'] = df2['Gls_Performance'].rolling(window=3).mean()
df2['xgSMA'] = df2['xG_Expected'].rolling(window=3).mean()

df2 = df2.dropna(subset=['xgSMA'])

df2 = df2.reset_index(drop=True)

fig,ax = plt.subplots(figsize=(12,8),facecolor=faceColor)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.grid(which='both',color='#dedede')
plt.xticks(np.linspace(0,50,10),['Sep','Oct','Nov','Dec','Jan','Feb','Mar','Apr'])
# plt.yticks(np.linspace(0,100,6),['','0%','20%','40%','60%','80%'])

ax.plot(df['xgSMA'],marker='o',markersize=10,color=otherColor,alpha=.2)
ax.plot(df['gSMA'],marker='o',markersize=10,color=otherColor)
# ax.plot(df2['xgSMA'],marker='o',markersize=10,color=oneColor,alpha=.2)
# ax.plot(df2['gSMA'],marker='o',markersize=10,color=oneColor)

# ax.text(x=1.5,y=4.1,s='Barcelona\'s xG is Going Up!?',fontsize=32,fontweight='bold',fontname='cmss10')

htext.fig_text(
    x=.15,y=.89,
    s='Barcelona\'s <Goals> and <xG> three match average',
    fontsize=18,
    color=basicColor,
    highlight_colors=[oneColor, '#a0c4ff'],
    highlight_weights = 'bold',
    fontname='cmss10',
    fontweight='bold'
)
# Out:
# [[Text(0.15, 0.9160416666666666, "Barcelona's "),
#   Text(0.25633680555555555, 0.9160416666666666, 'Goals'),
#   Text(0.30350115740740735, 0.9160416666666666, ' and '),
#   Text(0.3489293981481481, 0.9160416666666666, 'xG'),
#   Text(0.3723668981481481, 0.9160416666666666, ' three match average')]]

# %%
df = pd.read_csv('/work/assets/fbref/report/griezmann_summary.csv')
df2 = pd.read_csv('/work/assets/fbref/report/correasummary.csv')

df = df[df['Gls_Performance']!='On matchday squad, but did not play']

df = df.dropna(subset=['Gls_Performance'])
df = df.iloc[:-1,:]

df['gSMA'] = df['Gls_Performance'].rolling(window=3).mean()
df['xgSMA'] = df['xG_Expected'].rolling(window=3).mean()

df = df.dropna(subset=['xgSMA'])

df = df.reset_index(drop=True)

# df2 = df2.dropna(subset=['Gls_Performance'])
# df2 = df2.iloc[:-1,:]

# df2['gSMA'] = df2['Gls_Performance'].rolling(window=3).mean()
# df2['xgSMA'] = df2['xG_Expected'].rolling(window=3).mean()

# df2 = df2.dropna(subset=['xgSMA'])

# df2 = df2.reset_index(drop=True)

fig,ax = plt.subplots(figsize=(12,8),facecolor=faceColor)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.grid(which='both',color='#dedede')
plt.xticks(np.linspace(0,25,10),['Sep','Oct','Nov','Dec','Jan','Feb','Mar','Apr'])
# plt.yticks(np.linspace(0,100,6),['','0%','20%','40%','60%','80%'])

ax.plot(df['xgSMA'],marker='o',markersize=10,color=otherColor,alpha=.2)
ax.plot(df['gSMA'],marker='o',markersize=10,color=otherColor)
# ax.plot(df2['xgSMA'],marker='o',markersize=10,color=oneColor,alpha=.2)
# ax.plot(df2['gSMA'],marker='o',markersize=10,color=oneColor)

ax.text(x=-0.5,y=1.24,s='Barcelona\'s xG is Going Up!?',fontsize=32,fontweight='bold',fontname='cmss10')

htext.fig_text(
    x=.15,y=.89,
    s='Barcelona\'s <Goals> and <xG> three match average',
    fontsize=18,
    color=basicColor,
    highlight_colors=[oneColor, '#a0c4ff'],
    highlight_weights = 'bold',
    fontname='cmss10',
    fontweight='bold'
)
# Out:
# [[Text(0.15, 0.9160416666666666, "Barcelona's "),
#   Text(0.25633680555555555, 0.9160416666666666, 'Goals'),
#   Text(0.30350115740740735, 0.9160416666666666, ' and '),
#   Text(0.3489293981481481, 0.9160416666666666, 'xG'),
#   Text(0.3723668981481481, 0.9160416666666666, ' three match average')]]

# %%
df = pd.read_csv('/work/assets/fbref/report/griezmann_summary.csv')
df = df[df['Gls_Performance']!='On matchday squad, but did not play']
df['Gls_Performance'].astype('float64')
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      0.0
# 4      0.0
# 5      1.0
# 6      0.0
# 7      1.0
# 8      0.0
# 10     0.0
# 11     0.0
# 12     1.0
# 13     0.0
# 14     1.0
# 15     0.0
# 16     0.0
# 17     0.0
# 18     0.0
# 19     1.0
# 20     1.0
# 21     1.0
# 22     0.0
# 23     0.0
# 24     0.0
# 25     0.0
# 26     0.0
# 28     0.0
# 29     0.0
# 30     0.0
# 31     2.0
# 32     0.0
# 33     2.0
# 34     0.0
# 35     0.0
# 36     0.0
# 37     1.0
# 38     2.0
# 39     0.0
# 40     0.0
# 41     0.0
# 42     0.0
# 43     0.0
# 44     0.0
# 46     0.0
# 47     0.0
# 48     0.0
# 49     1.0
# 50     1.0
# 51     1.0
# 52     0.0
# 53     1.0
# 54     0.0
# 55     0.0
# 56     1.0
# 57     1.0
# 58     2.0
# 59     0.0
# 60     1.0
# 61    24.0
# Name: Gls_Performance, dtype: float64

# %%
df = pd.read_csv('/work/assets/fbref/report/felix_summary.csv')
df = df.iloc[:-1,:]

# %%
df = pd.read_csv('/work/assets/fbref/report/felix_summary.csv')
df2 = pd.read_csv('/work/assets/fbref/report/correasummary.csv')
df3 = pd.read_csv('/work/assets/fbref/report/griezmann_summary.csv')
df3['Gls_Performance']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 57     1
# 58     2
# 59     0
# 60     1
# 61    24
# Name: Gls_Performance, Length: 62, dtype: object

# %%
df2[]
# Out:
#     Unnamed: 0        Date  Day          Comp         Round Venue Result  \
# 0            0  2020-09-27  Sun       La Liga   Matchweek 3  Home  W 6–1
# 1            1  2020-09-30  Wed       La Liga   Matchweek 4  Away  D 0–0
# 2            2  2020-10-03  Sat       La Liga   Matchweek 5  Home  D 0–0
# 3            3  2020-10-17  Sat       La Liga   Matchweek 6  Away  W 2–0
# 4            4  2020-10-21  Wed  Champions Lg   Group stage  Away  L 0–4
# 5            5  2020-10-24  Sat       La Liga   Matchweek 7  Home  W 2–0
# 6            6  2020-10-27  Tue  Champions Lg   Group stage  Home  W 3–2
# 7            7  2020-10-31  Sat       La Liga   Matchweek 8  Away  W 3–1
# 8            8  2020-11-03  Tue  Champions Lg   Group stage  Away  D 1–1
# 9            9  2020-11-07  Sat       La Liga   Matchweek 9  Home  W 4–0
# 10          10  2020-11-21  Sat       La Liga  Matchweek 10  Home  W 1–0
# 11          11  2020-11-25  Wed  Champions Lg   Group stage  Home  D 0–0
# ...

# %%
print(np.__file__)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/__init__.py

# %%
fm = mpl.font_manager
mpl.rcParams['font.family'] = ['serif']
mpl.rcParams['font.serif'] = ['Times New Roman']

# %%
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": [],                    # use latex default serif font
    "font.sans-serif": ["DejaVu Sans"],  # use a specific sans-serif font
})

plt.figure(figsize=(4.5, 2.5))
plt.plot(range(5))
plt.text(0.5, 3., "serif")
# plt.text(0.5, 2., "ああああ", family="IPAexGothic")
plt.text(2.5, 2., "sans-serif", family="sans-serif")
plt.text(2.5, 1., "comic sans", family="Comic Sans MS")
plt.xlabel("µ is not $\\mu$")
plt.tight_layout(.5)

# %%
plt.rcParams["font.family"] = "IPAexGothic"

# %%
# !rm -fr ~/.cache/matplotlib

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])
HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>DejaVu Sans: <span style='font-family:DejaVu Sans; font-size: 24px;'>DejaVu Sans</p>
# <p>DejaVu Sans Display: <span style='font-family:DejaVu Sans Display; font-size: 24px;'>DejaVu Sans Display</p>
# <p>DejaVu Sans Mono: <span style='font-family:DejaVu Sans Mono; font-size: 24px;'>DejaVu Sans Mono</p>
# <p>DejaVu Serif: <span style='font-family:DejaVu Serif; font-size: 24px;'>DejaVu Serif</p>
# <p>DejaVu Serif Display: <span style='font-family:DejaVu Serif Display; font-size: 24px;'>DejaVu Serif Display</p>
# <p>STIXGeneral: <span style='font-family:STIXGeneral; font-size: 24px;'>STIXGeneral</p>
# <p>STIXNonUnicode: <span style='font-family:STIXNonUnicode; font-size: 24px;'>STIXNonUnicode</p>
# <p>STIXSizeFiveSym: <span style='font-family:STIXSizeFiveSym; font-size: 24px;'>STIXSizeFiveSym</p>
# <p>STIXSizeFourSym: <span style='font-family:STIXSizeFourSym; font-size: 24px;'>STIXSizeFourSym</p>
# ...

# %%
print(matplotlib.font_manager.__file__)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/font_manager.py

# %% [markdown]
# ## Font manager
#
# opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf
# このフォルダにジップファイルをわたし、解凍。

# %%
# !rm -fr ~/.cache/matplotlib

# %%
matplotlib.font_manager.fontManager.ttflist
# Out:
# [<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>,
#  <Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>,
#  <Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>,
#  <Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>,
#  <Font 'cmss10' (cmss10.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>,
#  <Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>,
# ...

# %%
print(matplotlib.matplotlib_fname())
print(matplotlib.get_configdir())
# !cp /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc /root/.config/matplotlib
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc
# /root/.config/matplotlib

# %%
cp 解凍したディレクトリ/*.ttf 1のファイルディレクトリ/fonts/ttf/
