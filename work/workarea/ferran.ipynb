# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects
import matplotlib.font_manager as fm
from highlight_text import fig_text, ax_text

from mplsoccer import Pitch

from PIL import Image
import urllib
import os

# %%
spaceMono_bold = 'https://github.com/googlefonts/spacemono/blob/main/fonts/SpaceMono-BoldItalic.ttf?raw=true'

from mplsoccer import FontManager
monoBFont = FontManager(spaceMono_bold)

# %%
df = pd.read_csv('/work/assets/10312022_epl_shots.csv', index_col=0)
df
# Out:
#          shot_id    event_type  team_id  player_id          player_name  \
# 0     2443406693  AttemptSaved     8654     523825         Jarrod Bowen
# 1     2443411697  AttemptSaved     8654     158545      Michail Antonio
# 2     2443406789          Miss     8654     158545      Michail Antonio
# 3     2443411153  AttemptSaved     8456     169200      Kevin De Bruyne
# 4     2443414481          Miss     8456     169200      Kevin De Bruyne
# ...          ...           ...      ...        ...                  ...
# 3212  2479039649  AttemptSaved     9879     182962          Tom Cairney
# 3213  2479040285  AttemptSaved     9879     502420        Harrison Reed
# 3214  2479040459  AttemptSaved     9879      94086              Willian
# 3215  2479043471          Miss     9879     351860  Aleksandar Mitrovic
# 3216  2479045683          Miss     9879     351860  Aleksandar Mitrovic
#
#          shot_x     shot_y  min  min_added  is_blocked  ...  goal_crossed_z  \
# 0     95.929825  33.008751    2        NaN        True  ...        1.220000
# 1     96.991227  38.704525    2        NaN        True  ...        1.245684
# 2     97.087716  34.686251    3        NaN       False  ...        3.376828
# 3     81.471358  22.668026    9        NaN        True  ...        1.220000
# 4     90.699997  25.129062   14        NaN       False  ...        0.269684
# ...         ...        ...  ...        ...         ...  ...             ...
# 3212  90.699997  38.032142   78        NaN        True  ...        1.220000
# 3213  83.723785  21.406879   79        NaN        True  ...        1.220000
# 3214  90.900002  41.367812   79        NaN       False  ...        0.122000
# 3215  93.400002  28.875237   86        NaN       False  ...        0.269684
# 3216  93.000000  34.838749   90        0.0       False  ...        6.270483
#
#             xG    xGOT  shot_type    situation      period  is_own_goal  \
# 0     0.173840     NaN   LeftFoot   FromCorner   FirstHalf        False
# 1     0.082090     NaN   LeftFoot  RegularPlay   FirstHalf        False
# 2     0.090813     NaN     Header   FromCorner   FirstHalf        False
# 3     0.019727     NaN   LeftFoot  RegularPlay   FirstHalf        False
# 4     0.138967     NaN  RightFoot  RegularPlay   FirstHalf        False
# ...        ...     ...        ...          ...         ...          ...
# 3212  0.072628     NaN   LeftFoot  RegularPlay  SecondHalf        False
# 3213  0.026571     NaN  RightFoot   FromCorner  SecondHalf        False
# 3214  0.088496  0.1026  RightFoot  RegularPlay  SecondHalf        False
# 3215  0.017457     NaN     Header   FromCorner  SecondHalf        False
# 3216  0.057478     NaN  RightFoot  RegularPlay  SecondHalf        False
#
#        on_goal_x  on_goal_y short_name
# 0      55.892857  14.239029        NaN
# 1       7.782738  14.538798        NaN
# 2     102.929726  39.412087        NaN
# 3      62.247024  14.239029        NaN
# 4       0.000000   3.147575        NaN
# ...          ...        ...        ...
# 3212   66.785714  14.239029        NaN
# 3213   45.000000  14.239029        NaN
# 3214   59.523810   1.423903        NaN
# 3215  164.041950   3.147575        NaN
# 3216  136.547735  73.184906        NaN
#
# [3217 rows x 24 columns]

# %%
top_scorers = (
    df[(df['is_own_goal'] == False) & (df['event_type'] == 'Goal')]
    .groupby(['player_id', 'player_name', 'event_type', 'team_id'])
    .agg({'shot_id':'count'})
    .reset_index()
    .rename(columns={'shot_id':'goals'})
)
top_scorers = top_scorers.sort_values(by='goals', ascending=False).head(6).reset_index(drop=True)
top_scorers
# Out:
#    player_id           player_name event_type  team_id  goals
# 0     737066  Erling Braut Haaland       Goal     8456     17
# 1     194165            Harry Kane       Goal     8586     10
# 2     351860   Aleksandar Mitrovic       Goal     9879      9
# 3     408987            Ivan Toney       Goal     9937      8
# 4     318615      Leandro Trossard       Goal    10204      7
# 5     442277        Miguel Almiron       Goal    10261      7
