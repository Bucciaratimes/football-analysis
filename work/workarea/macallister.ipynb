# %% [markdown]
# # Report: Alexis Mac Allister

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats
from PIL import Image
import matplotlib as mpl
import matplotlib.patheffects
import matplotlib.pyplot as plt
from matplotlib.markers import MarkerStyle
import matplotlib.image as mpimg
from mplsoccer import Pitch, add_image
from adjustText import adjust_text
from highlight_text import htext
from pywaffle import Waffle
from scraype import FbrefScrayper

# %%
text_color = '#CECECD'
background_color = "#F8F8FF"
scatter_color = '#D7B013'
secondary_color = '#C0C0C0'
mpl.rcParams['xtick.color'] = '#131313'
mpl.rcParams['ytick.color'] = '#131313'

image = Image.open(f'/work/assets/image/brighton.png').convert('P')
logo = image.copy()
# logo.putalpha(100)
# logo

# %%
fig, ax = plt.subplots(figsize=(10,7),facecolor='#f8f8ff')
pitch = Pitch(
    pitch_type='statsbomb',
    goal_type = 'box',
    pitch_color = '#f8f8ff',
    line_color = 'dodgerblue', 
    figsize=(13.5,8),
    constrained_layout = True,
    tight_layout = False,
    line_zorder=1, linewidth=0.5
)
pitch.draw(ax=ax)

# image = Image.open('/work/assets/image/brighton.png')
# alpha = Image.new("L", image.size, 70)
# ax_image = fig.add_axes((0.264, 0.245, 0.5, 0.5))
# ax_image.axis('off')
# image.putalpha(alpha)
# ax_image.imshow(image)
ax_image = fig.add_axes((.23, 0.23, 0.58, 0.58))
ax_image.axis('off')
ax_image.imshow(logo)

plt.savefig(f'/work/output/report/logo.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %% [markdown]
# ## Play Time

# %%
df = pd.read_csv('/work/assets/fbref/report/mac_summary.csv')

for idx,row in df.iterrows():
    if row['Min']=='On matchday squad, but did not play':
        df.loc[idx,'Min'] = 0
        
df = df[(df['Comp']!='FA Cup')&(df['Comp']!='EFL Cup')&(df['Comp']!='WCQ')]

df_time = df[['Min','Date']]
df_time = df_time.dropna()
# for idx, row in df_time.iterrows():
#     if len(row['Min']) > 2:
#         df_time = df_time.drop(index=idx,axis=0)

df_time.sort_values(by='Date')

# y = [0]
# for i in df_time['Min']:
#     y.append(y[-1]+int(i))

y = []
for i in df_time['Min']:
    y.append(int(i))
    
_y = []
for i,val in enumerate(y):
    ys = np.mean(y[i:i+3])
    _y.append(ys)
    
_y[0:0] = [0,0,0]
# _y[5:5] = [0]
# _y[7:7] = [0]

# _y[-5:-5] = [0]
# _y[18:18] = [0]
# _y[21:21] = [0]
len(_y)
# _y
# Out:
# 24

# %%
df = pd.read_csv('/work/assets/fbref/report/lallana_summary.csv')

for idx,row in df.iterrows():
    if row['Min']=='On matchday squad, but did not play':
        df.loc[idx,'Min'] = 0
        
df = df[(df['Comp']!='FA Cup')&(df['Comp']!='EFL Cup')&(df['Comp']!='WCQ')]


df_time = df[['Min','Date']]
df_time = df_time.dropna()

# for idx, row in df_time.iterrows():
#     if len(row['Min']) > 2:
#         df_time = df_time.drop(index=idx,axis=0)

df_time.sort_values(by='Date')

y2 = []
for i in df_time['Min']:
    y2.append(int(i))

_y2 = []
for i,val in enumerate(y2):
    y = np.mean(y2[i:i+3])
#     if i == len(y2)-2:
#         break
    _y2.append(y)

# _y2[1:1] = [0]
# _y2[3:3] = [0]
# _y2[5:5] = [0]
# _y2[23:23] = [0]
# _y2[28:28] = [0]

len(_y2)
# _y2
# Out:
# 24

# %%
df = pd.read_csv('/work/assets/fbref/report/trossard_summary.csv')

for idx,row in df.iterrows():
    if row['Min']=='On matchday squad, but did not play':
        df.loc[idx,'Min'] = 0
        
df = df[(df['Comp']!='FA Cup')&(df['Comp']!='EFL Cup')&(df['Comp']!='UEFA Nations League')&(df['Comp']!='Friendlies (M)')]

df_time = df[['Min','Date']]
df_time = df_time.dropna()
# for idx, row in df_time.iterrows():
#     if len(row['Min']) > 2:
#         df_time = df_time.drop(index=idx,axis=0)

df_time.sort_values(by='Date')

y3 = []
for i in df_time['Min']:
    y3.append(int(i))

_y3 = []
for i,val in enumerate(y3):
    y = np.mean(y3[i:i+3])
#     i+=4
    if i == len(y3)-2:
        break
    _y3.append(y)


# _y3 = _y3
# _y3[1:1] = [0]
# _y3[3:3] = [0]
# _y3[5:5] = [0]
# _y3[-13:-13] = [0]
_y3 = _y3[:-1]

len(_y3)
# Out:
# 24

# %%
df = pd.read_csv('/work/assets/fbref/report/gross_summary.csv')

for idx,row in df.iterrows():
    if row['Min']=='On matchday squad, but did not play':
        df.loc[idx,'Min'] = 0
        
df = df[(df['Comp']!='FA Cup')&(df['Comp']!='EFL Cup')]

df_time = df[['Min','Date']]
df_time = df_time.dropna()
# for idx, row in df_time.iterrows():
#     if len(row['Min']) > 2:
#         df_time = df_time.drop(index=idx,axis=0)

df_time.sort_values(by='Date')

# y = [0]
# for i in df_time['Min']:
#     y.append(y[-1]+int(i))

y4 = []
for i in df_time['Min']:
    y4.append(int(i))
    
_y4 = []
for i,val in enumerate(y4):
    ys = np.mean(y4[i:i+3])
    _y4.append(ys)
    

_y4 = _y4[:-5]

len(_y4)
# Out:
# 24

# %%
fig, ax = plt.subplots(
    facecolor=background_color, figsize=(9,6), dpi=150
)
ax.set_facecolor(background_color)
ax.grid(color='#444444')
fig.text(x=.75,y=.05,s='Data via fbref.com',color='#131313', fontsize=10)
htext.fig_text(
    x=.15,y=.98,
    s="This Figure shows the Rivalry \n                between <Mac> <Lallana> <Gross> and <Trossard>",
    fontsize=14,
    color='#131313',
    highlight_colors=['#4361ee','#f72585','#6411ad','#e36414'],
    highlight_weights = 'bold',
    fontname='monospace'
)
# htext.fig_text(
#     x=.15,y=.93,
#     s='',
#     fontsize=13,
#     color='white',
#     highlight_colors=['#131313'],
#     highlight_weights = 'bold',
#     fontname='monospace'
    
# )
htext.fig_text(
    x=.15,y=.885,
    s="Correlation Coefficient:\n        Mac&Lallana <-0.690> Mac&Gros <-0.134> Mac&Tro <0.091>\n        Lalla&Gros <0.531>  Lalla&Tro <0.104> Tro&Gros <-0.318>",
    fontsize=9,
    color='#131313',
    highlight_colors=['seagreen','seagreen','seagreen','seagreen','seagreen','seagreen'],
    highlight_weights = 'bold',
#     highlight_styles = 'oblique',
    fontname='monospace'
)
ax.set_ylabel('Average Time',color='#131313',fontsize=11)

ax.plot(_y,color='#4361ee',marker='o',markersize=12)
ax.plot(_y2,color='#f72585',marker='o',markersize=12)
ax.plot(_y3,color='#e36414',marker='o',markersize=12)
ax.plot(_y4,color='#6411ad',marker='o',markersize=12)


ax.grid(False)

plt.xticks([-1,0,4,8,12,16,20,24],['Sep','Oct','Nov','Dec','Jan','Feb','Mar','Apr'])

image = Image.open('/work/assets/image/brighton.png')
ax_image = fig.add_axes((0.79, 0.94, 0.18, 0.18))
ax_image.axis('off')
ax_image.imshow(image)
plt.savefig(f'/work/output/report/mac_time.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %%
_y = [round(i) for i in _y]
_y2 = [round(i) for i in _y2]
r = np.corrcoef(_y,_y4)[0][1]
r
# Out:
# -0.1346129862372807

# %% [markdown]
# ## Goal or Shot Creating Ability

# %%
df = pd.read_csv('/work/assets/fbref/report/brighton.csv')
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Player',
#  'Nation_x',
#  'Pos_x',
#  'Age_x',
#  'MP_Playing Time',
#  'Starts_Playing Time',
#  'Min_Playing Time',
#  '90s_Playing Time',
#  'Gls_Performance',
#  'Ast_Performance',
#  'G-PK_Performance',
#  'PK_Performance',
#  'PKatt_Performance',
#  'CrdY_Performance',
#  'CrdR_Performance',
#  'Gls_Per 90 Minutes',
#  'Ast_Per 90 Minutes',
#  'G+A_Per 90 Minutes',
#  'G-PK_Per 90 Minutes',
#  'G+A-PK_Per 90 Minutes',
#  'xG_Expected_x',
#  'npxG_Expected_x',
#  'xA_Expected',
#  'npxG+xA_Expected',
#  'xG_Per 90 Minutes',
#  'xA_Per 90 Minutes',
#  'xG+xA_Per 90 Minutes',
#  'npxG_Per 90 Minutes',
#  'npxG+xA_Per 90 Minutes',
#  'Nation_y',
#  'Pos_y',
#  'Age_y',
#  '90s_x',
#  'Gls_Standard',
#  'Sh_Standard',
#  'SoT_Standard',
#  'SoT%_Standard',
#  'Sh/90_Standard',
#  'SoT/90_Standard',
#  'G/Sh_Standard',
#  'G/SoT_Standard',
#  'Dist_Standard',
#  'FK_Standard',
#  'PK_Standard',
#  'PKatt_Standard',
#  'xG_Expected_y',
#  'npxG_Expected_y',
#  'npxG/Sh_Expected',
#  'G-xG_Expected',
#  'np:G-xG_Expected',
#  'Nation_x.1',
#  'Pos_x.1',
#  'Age_x.1',
#  '90s_y',
#  'Cmp_Total',
#  'Att_Total',
#  'Cmp%_Total',
#  'TotDist_Total',
#  'PrgDist_Total',
#  'Cmp_Short',
#  'Att_Short',
#  'Cmp%_Short',
#  'Cmp_Medium',
#  'Att_Medium',
#  'Cmp%_Medium',
#  'Cmp_Long',
#  'Att_Long',
#  'Cmp%_Long',
#  'Ast',
#  'xA',
#  'A-xA',
#  'KP',
#  '1/3',
#  'PPA',
#  'CrsPA',
#  'Prog',
#  'Nation_y.1',
#  'Pos_y.1',
#  'Age_y.1',
#  '90s_x.1',
#  'Att',
#  'Live_Pass Types',
#  'Dead_Pass Types',
#  'FK_Pass Types',
#  'TB_Pass Types',
#  'Press_Pass Types',
#  'Sw_Pass Types',
#  'Crs_Pass Types',
#  'CK_Pass Types',
#  'In_Corner Kicks',
#  'Out_Corner Kicks',
#  'Str_Corner Kicks',
#  'Ground_Height',
#  'Low_Height',
#  'High_Height',
#  'Left_Body Parts',
#  'Right_Body Parts',
#  'Head_Body Parts',
#  'TI_Body Parts',
#  'Other_Body Parts',
#  'Cmp_Outcomes',
#  'Off_Outcomes',
#  'Out_Outcomes',
#  'Int_Outcomes',
#  'Blocks_Outcomes',
#  'Nation_x.2',
#  'Pos_x.2',
#  'Age_x.2',
#  '90s_y.1',
#  'SCA_SCA',
#  'SCA90_SCA',
#  'PassLive_SCA Types',
#  'PassDead_SCA Types',
#  'Drib_SCA Types',
#  'Sh_SCA Types',
#  'Fld_SCA Types',
#  'Def_SCA Types',
#  'GCA_GCA',
#  'GCA90_GCA',
#  'PassLive_GCA Types',
#  'PassDead_GCA Types',
#  'Drib_GCA Types',
#  'Sh_GCA Types',
#  'Fld_GCA Types',
#  'Def_GCA Types',
#  'OG_GCA Types',
#  'Nation_y.2',
#  'Pos_y.2',
#  'Age_y.2',
#  '90s_x.2',
#  'Tkl_Tackles',
#  'TklW_Tackles',
#  'Def 3rd_Tackles',
#  'Mid 3rd_Tackles',
#  'Att 3rd_Tackles',
#  'Tkl_Vs Dribbles',
#  'Att_Vs Dribbles',
#  'Tkl%_Vs Dribbles',
#  'Past_Vs Dribbles',
#  'Press_Pressures',
#  'Succ_Pressures',
#  '%_Pressures',
#  'Def 3rd_Pressures',
#  'Mid 3rd_Pressures',
#  'Att 3rd_Pressures',
#  'Blocks_Blocks',
#  'Sh_Blocks',
#  'ShSv_Blocks',
#  'Pass_Blocks',
#  'Int',
#  'Tkl+Int',
#  'Clr',
#  'Err',
#  'Nation',
#  'Pos',
#  'Age',
#  '90s_y.2',
#  'Touches_Touches',
#  'Def Pen_Touches',
#  'Def 3rd_Touches',
#  'Mid 3rd_Touches',
#  'Att 3rd_Touches',
#  'Att Pen_Touches',
#  'Live_Touches',
#  'Succ_Dribbles',
#  'Att_Dribbles',
#  'Succ%_Dribbles',
#  '#Pl_Dribbles',
#  'Megs_Dribbles',
#  'Carries_Carries',
#  'TotDist_Carries',
#  'PrgDist_Carries',
#  'Prog_Carries',
#  '1/3_Carries',
#  'CPA_Carries',
#  'Mis_Carries',
#  'Dis_Carries',
#  'Targ_Receiving',
#  'Rec_Receiving',
#  'Rec%_Receiving',
#  'Prog_Receiving']

# %%
df = pd.read_csv('/work/assets/fbref/report/brighton.csv')
df = df[['Player', '90s_Playing Time', 'Tkl+Int', 'SCA_SCA', 'Press_Pressures','%_Pressures','Targ_Receiving']]
df['x'] = df['Tkl+Int']/df['90s_Playing Time']
df['y'] = df['Press_Pressures']/df['90s_Playing Time']
df = df.dropna()
df.drop(axis=0,index=[26,27],inplace=True)
# df.columns.tolist()
fig, ax = plt.subplots(
    facecolor='#F8F8FF', figsize=(9,6), dpi=150
)
ax.set_facecolor(background_color)
fig.text(x=.75,y=.05,s='Data via fbref.com',color='#131313', fontsize=7)
htext.fig_text(
    x=.15,y=.98,
    s="<Brighton><'s Scatter>",
    fontsize=16,
    color='white',
    highlight_colors=['#4361ee','#131313'],
    highlight_weights = 'bold',
#     highlight_styles = 'oblique',
    fontname='monospace'
)
# htext.fig_text(
#     x=.15,y=.93,
#     s='<Premier League | 2020/2021>',
#     fontsize=13,
#     color='white',
#     highlight_colors=['#131313'],
#     fontname='monospace'
# )
htext.fig_text(
    x=.15,y=.895,
    s="This Figure shows Brighton's <SCA> and <Int+Tackle>'s Share.\nespecially <Mac Allister>, <Lallana>, <Gross> and <Trossard> have contributed",
    fontsize=13,
    color='#131313',
    highlight_colors=['#3a2e39','#3a2e39','#4361ee','#f72585', '#6411ad', '#e36414'],
    highlight_weights = 'bold',
    fontname='monospace'
    
)
ax.set_xlabel('Intercept + Tackle',color='#131313',fontsize=11)
ax.set_ylabel('Press Attempt',color='#131313',fontsize=11)
# ax.set_ylim([-5,65])

for idx,row in df.iterrows():
    if row['Player'] == 'Alexis Mac Allister':
        ax.scatter(row['x'],row['y'],s=258,c='#4361ee',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Adam Lallana':
        ax.scatter(row['x'],row['y'],s=258,c='#f72585',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Leandro Trossard':
        ax.scatter(row['x'],row['y'],s=258,c='#e36414',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Pascal Groß':
        ax.scatter(row['x'],row['y'],s=258,c='#6411ad',marker='o',hatch=5*'/',zorder=5)
        
    ax.scatter(row['x'],row['y'], s=170 ,hatch=5*'/', alpha=.2)
    
text_values = df[['x','y','Player']].values 
texts = [
    ax.text(val[0],val[1],val[2],
            size=8, color=text_color, zorder=5,
            fontfamily='monospace') for val in text_values
]
[text.set_path_effects([mpl.patheffects.withStroke(
    linewidth=3, foreground='#131313'
)]) for text in texts]

adjust_text(
    texts, autoalign='y',
    only_move={'points':'y', 'text':'xy'}, 
    force_objects=(0.5, 3), force_text=(0.5, 3), 
    force_points=(0.5, 7)
)

max_x = df['x'].max()
max_x = round(max_x)
max_y = df['y'].max()
max_y = round(max_y)

median_x = df['x'].median()
median_y = df['y'].median()

ax.plot(
    [median_x,median_x],[0,max_y+.03],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)
ax.plot(
    [0,max_x],[median_y,median_y],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)

image = Image.open('/work/assets/image/brighton.png')
ax_image = fig.add_axes((0.72, 0.94, 0.18, 0.18))
ax_image.axis('off')
ax_image.imshow(image)
plt.savefig(f'/work/output/report/mac_scatter.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %%
df = pd.read_csv('/work/assets/fbref/report/brighton.csv')

df = df.dropna()
y='npxG+xA_Expected'
x='SCA_SCA'
df['x'] = df[x]/df['90s_Playing Time']
df['y'] = df[y]/df['90s_Playing Time']

fig, ax = plt.subplots(
    facecolor=background_color, figsize=(9,6), dpi=150
)
ax.set_facecolor(background_color)
# ax.grid(color='#444444')
fig.text(x=.75,y=.05,s='Data via fbref.com',color='#131313', fontsize=7)
htext.fig_text(
    x=.15,y=.98,
    s="<Brighton><'s Scatter>",
    fontsize=16,
    color='white',
    highlight_colors=['#4361ee','#131313'],
    highlight_weights = 'bold',
#     highlight_styles = 'oblique',
    fontname='monospace'
)
# htext.fig_text(
#     x=.15,y=.93,
#     s='<Premier League | 2020/2021>',
#     fontsize=13,
#     color='white',
#     highlight_colors=['#131313'],
#     fontname='monospace'
# )
htext.fig_text(
    x=.15,y=.895,
    s=f"This Figure shows Brighton's Share of <Press Attempt> and <nPxG + xA>.\nespecially <Mac>, <Lallana>, <Gross> and <Trossard> have contributed to",
    fontsize=13,
    color='#131313',
    highlight_colors=['#3a2e39','#3a2e39','#4361ee','#f72585','#6411ad','#e36414'],
    highlight_weights = 'bold',
    fontname='monospace'
    
)
ax.set_xlabel('Shot Create Action',color='#131313',fontsize=11)
ax.set_ylabel('npxG+xA',color='#131313',fontsize=11)
ax.set_ylim([-.05,.70])

for idx,row in df.iterrows():
    if row['Player'] == 'Alexis Mac Allister':
        ax.scatter(row['x'],row['y'],s=258,c='#4361ee',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Adam Lallana':
        ax.scatter(row['x'],row['y'],s=258,c='#f72585',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Leandro Trossard':
        ax.scatter(row['x'],row['y'],s=258,c='#e36414',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Pascal Groß':
        ax.scatter(row['x'],row['y'],s=258,c='#6411ad',marker='o',hatch=5*'/',zorder=5)
    ax.scatter(row['x'],row['y'], s=170 ,hatch=5*'/', alpha=.2)
    
text_values = df[['x','y','Player']].values 
texts = [
    ax.text(val[0],val[1],val[2],
            size=8, color=text_color, zorder=5,
            fontfamily='monospace') for val in text_values
]
[text.set_path_effects([mpl.patheffects.withStroke(
    linewidth=3, foreground='#131313'
)]) for text in texts]

adjust_text(
    texts, autoalign='y',
    only_move={'points':'y', 'text':'xy'}, 
    force_objects=(0.5, 3), force_text=(0.5, 3), 
    force_points=(0.5, 7)
)

max_x = df['x'].max()
max_x = round(max_x)
max_y = df['y'].max()
max_y = round(max_y)

median_x = df['x'].median()
median_y = df['y'].median()

ax.plot(
    [median_x,median_x],[0,max_y+.03],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)
ax.plot(
    [0,max_x+.4],[median_y,median_y],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)

image = Image.open('/work/assets/image/brighton.png')
ax_image = fig.add_axes((0.72, 0.94, 0.18, 0.18))
ax_image.axis('off')
ax_image.imshow(image)
plt.savefig(f'/work/output/report/mac_scatter2.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %%
df = pd.read_csv('/work/assets/fbref/report/brighton.csv')
df = df.dropna()
x='Gls_Per 90 Minutes'
y='Ast_Per 90 Minutes'

df['x'] = df[x]
df['y'] = df[y]

fig, ax = plt.subplots(
    facecolor=background_color, figsize=(9,6), dpi=150
)
ax.set_facecolor(background_color)

fig.text(x=.75,y=.05,s='Data via fbref.com',color='#131313', fontsize=7)
htext.fig_text(
    x=.15,y=.98,
    s="<Brighton><'s Scatter>",
    fontsize=16,
    color='white',
    highlight_colors=['#4361ee','#131313'],
    highlight_weights = 'bold',
    fontname='monospace'
)
# htext.fig_text(
#     x=.15,y=.93,
#     s='<Premier League | 2020/2021>',
#     fontsize=13,
#     color='white',
#     highlight_colors=['#131313'],
#     fontname='monospace'
# )
htext.fig_text(
    x=.15,y=.895,
    s=f"This Figure shows Brighton's Share of <{x[:3]}> and <{y[:3]}>\nespecially <Mac>, <Lallana>,<Gross> and <Trossard> have contributed to",
    fontsize=13,
    color='#131313',
    highlight_colors=['#3a2e39','#3a2e39','#4361ee','#f72585','#6411ad','#e36414'],
    highlight_weights = 'bold',
    fontname='monospace'
    
)
ax.set_xlabel('Goals Per 90',color='#131313',fontsize=11)
ax.set_ylabel('Assist Per 90',color='#131313',fontsize=11)
ax.set_ylim([-.03,.45])

for idx,row in df.iterrows():
    if row['Player'] == 'Alexis Mac Allister':
        ax.scatter(row['x'],row['y'],s=258,c='#4361ee',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Adam Lallana':
        ax.scatter(row['x'],row['y'],s=258,c='#f72585',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Leandro Trossard':
        ax.scatter(row['x'],row['y'],s=258,c='#e36414',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Pascal Groß':
        ax.scatter(row['x'],row['y'],s=258,c='#6411ad',marker='o',hatch=5*'/',zorder=5)
    ax.scatter(row['x'],row['y'], s=170 ,hatch=5*'/', alpha=.2)
    
text_values = df[['x','y','Player']].values 
texts = [
    ax.text(val[0],val[1],val[2],
            size=8, color=text_color, zorder=5,
            fontfamily='monospace') for val in text_values
]
[text.set_path_effects([mpl.patheffects.withStroke(
    linewidth=3, foreground='#131313'
)]) for text in texts]

adjust_text(
    texts, autoalign='y',
    only_move={'points':'y', 'text':'xy'}, 
    force_objects=(0.5, 3), force_text=(0.5, 3), 
    force_points=(0.5, 7)
)

max_x = df['x'].max()
max_x = round(max_x)
max_y = df['y'].max()
max_y = round(max_y)

median_x = df['x'].median()
median_y = df['y'].median()

ax.plot(
    [median_x,median_x],[0,max_y+.5],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)
ax.plot(
    [0,max_x+.4],[median_y,median_y],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)

image = Image.open('/work/assets/image/brighton.png')
ax_image = fig.add_axes((0.72, 0.94, 0.18, 0.18))
ax_image.axis('off')
ax_image.imshow(image)
plt.savefig(f'/work/output/report/mac_scatter3.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %%
df = pd.read_csv('/work/assets/fbref/report/brighton.csv')
df = df.dropna()
x='CPA_Carries'
y='PPA'
# df.columns.tolist()
df['x'] = df[x]/df['90s_Playing Time']
df['y'] = df[y]/df['90s_Playing Time']

fig, ax = plt.subplots(
    facecolor=background_color, figsize=(9,6), dpi=150
)
ax.set_facecolor(background_color)

fig.text(x=.75,y=.05,s='Data via fbref.com',color='#131313', fontsize=7)
htext.fig_text(
    x=.15,y=.98,
    s="<Brighton><'s Scatter>",
    fontsize=16,
    color='white',
    highlight_colors=['#4361ee','#131313'],
    highlight_weights = 'bold',
    fontname='monospace'
)
# htext.fig_text(
#     x=.15,y=.93,
#     s='<Premier League | 2020/2021>',
#     fontsize=13,
#     color='white',
#     highlight_colors=['#131313'],
#     fontname='monospace'
# )
htext.fig_text(
    x=.15,y=.895,
    s=f"This Figure shows Brighton's Share of <{x[:3]}> and <{y}>\nespecially <Mac>, <Lallana>, <Gross> and <Trossard> have contributed to",
    fontsize=13,
    color='#131313',
    highlight_colors=['#3a2e39','#3a2e39','#4361ee','#f72585','#6411ad','#e36414'],
    highlight_weights = 'bold',
    fontname='monospace'
    
)
ax.set_xlabel('Carries into Pena',color='#131313',fontsize=11)
ax.set_ylabel('Passes into Pena',color='#131313',fontsize=11)

for idx,row in df.iterrows():
    if row['Player'] == 'Alexis Mac Allister':
        ax.scatter(row['x'],row['y'],s=258,c='#4361ee',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Adam Lallana':
        ax.scatter(row['x'],row['y'],s=258,c='#f72585',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Leandro Trossard':
        ax.scatter(row['x'],row['y'],s=258,c='#e36414',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Pascal Groß':
        ax.scatter(row['x'],row['y'],s=258,c='#6411ad',marker='o',hatch=5*'/',zorder=5)
    ax.scatter(row['x'],row['y'], s=170 ,hatch=5*'/', alpha=.2)
    
text_values = df[['x','y','Player']].values 
texts = [
    ax.text(val[0],val[1],val[2],
            size=8, color=text_color, zorder=5,
            fontfamily='monospace') for val in text_values
]
[text.set_path_effects([mpl.patheffects.withStroke(
    linewidth=3, foreground='#131313'
)]) for text in texts]

adjust_text(
    texts, autoalign='y',
    only_move={'points':'y', 'text':'xy'}, 
    force_objects=(0.5, 3), force_text=(0.5, 3), 
    force_points=(0.5, 7)
)

max_x = df['x'].max()
max_x = round(max_x)
max_y = df['y'].max()
max_y = round(max_y)

median_x = df['x'].median()
median_y = df['y'].median()

ax.plot(
    [median_x,median_x],[0,max_y+.03],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)
ax.plot(
    [0,max_x+.4],[median_y,median_y],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)

image = Image.open('/work/assets/image/brighton.png')
ax_image = fig.add_axes((0.72, 0.94, 0.18, 0.18))
ax_image.axis('off')
ax_image.imshow(image)
plt.savefig(f'/work/output/report/mac_scatter4.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %%
df = pd.read_csv('/work/assets/fbref/report/brighton.csv')
df = df.dropna()
x = 'Succ_Dribbles'
y = 'Att_Dribbles'

# df.columns.tolist()
df['x'] = df[x]/df['90s_Playing Time']
df['y'] = df[y]/df['90s_Playing Time']

fig, ax = plt.subplots(
    facecolor=background_color, figsize=(9,6), dpi=150
)
ax.set_facecolor(background_color)

fig.text(x=.75,y=.05,s='Data via fbref.com',color='#131313', fontsize=7)
htext.fig_text(
    x=.15,y=.98,
    s="<Brighton><'s Scatter>",
    fontsize=16,
    color='white',
    highlight_colors=['#4361ee','#131313'],
    highlight_weights = 'bold',
    fontname='monospace'
)
# htext.fig_text(
#     x=.15,y=.93,
#     s='<Premier League | 2020/2021>',
#     fontsize=13,
#     color='white',
#     highlight_colors=['#131313'],
#     fontname='monospace'
# )
htext.fig_text(
    x=.15,y=.895,
    s=f"This Figure shows Brighton's Share of <{x[:3]}> and <{y}>\nespecially <Mac>, <Lallana>,<Gross> and <Trossard> have contributed to",
    fontsize=13,
    color='#131313',
    highlight_colors=['#3a2e39','#3a2e39','#4361ee','#f72585','#6411ad','#e36414'],
    highlight_weights = 'bold',
    fontname='monospace'
    
)
ax.set_xlabel('Number of Success Dribble',color='#131313',fontsize=11)
ax.set_ylabel('Number of Attempt Dribble',color='#131313',fontsize=11)

for idx,row in df.iterrows():
    if row['Player'] == 'Alexis Mac Allister':
        ax.scatter(row['x'],row['y'],s=258,c='#4361ee',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Adam Lallana':
        ax.scatter(row['x'],row['y'],s=258,c='#f72585',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Leandro Trossard':
        ax.scatter(row['x'],row['y'],s=258,c='#e36414',marker='o',hatch=5*'/',zorder=5)
    elif row['Player'] == 'Pascal Groß':
        ax.scatter(row['x'],row['y'],s=258,c='#6411ad',marker='o',hatch=5*'/',zorder=5)
    ax.scatter(row['x'],row['y'], s=170 ,hatch=5*'/', alpha=.2)
    
text_values = df[['x','y','Player']].values 
texts = [
    ax.text(val[0],val[1],val[2],
            size=8, color=text_color, zorder=5,
            fontfamily='monospace') for val in text_values
]
[text.set_path_effects([mpl.patheffects.withStroke(
    linewidth=3, foreground='#131313'
)]) for text in texts]

adjust_text(
    texts, autoalign='y',
    only_move={'points':'y', 'text':'xy'}, 
    force_objects=(0.5, 3), force_text=(0.5, 3), 
    force_points=(0.5, 7)
)

max_x = df['x'].max()
max_x = round(max_x)
max_y = df['y'].max()
max_y = round(max_y)

median_x = df['x'].median()
median_y = df['y'].median()

ax.plot(
    [median_x,median_x],[0,max_y+.03],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)
ax.plot(
    [0,max_x+.4],[median_y,median_y],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)

image = Image.open('/work/assets/image/brighton.png')
ax_image = fig.add_axes((0.72, 0.94, 0.18, 0.18))
ax_image.axis('off')
ax_image.imshow(image)
plt.savefig(f'/work/output/report/mac_scatter5.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %%
df0 = pd.read_csv('/work/assets/fbref/report/city.csv')
df0['Squads'] = 'City'
df1 = pd.read_csv('/work/assets/fbref/report/tottenham.csv')
df1['Squads'] = 'Tottenham'
df2 = pd.read_csv('/work/assets/fbref/report/united.csv')
df2['Squads'] = 'United'
df3 = pd.read_csv('/work/assets/fbref/report/liverpool.csv')
df3['Squads'] = 'Liverpool'
df4 = pd.read_csv('/work/assets/fbref/report/brighton.csv')
df4['Squads'] = 'Brighton'


dfs = [df0,df1,df2,df3,df4]
df = pd.concat(dfs)

# cmap = plt.cm.get_cmap('magma')
# colors = cmap(df['count']/df['count'].max())

# df.columns.tolist()

# %%
# df = df.drop(columns=['Unnamed: 0'])

# %%
bdf = pd.read_csv('/work/assets/fbref/report/brighton.csv')
bdf = bdf[['Player', 'Cmp%_Short', 'Cmp%_Medium', 'Cmp%_Long']]
# bdf = bdf.drop(index=[26,27])
bdf.head()

fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(30,25),facecolor=background_color)
axes = axes.ravel()

X = range(20,100,33)
for i,num in enumerate([4,11,14]):
    axes[i].set_facecolor(background_color)
    axes[i].imshow(logo,extent=[0, 100, 0, 100])
    axes[i].set_ylim(0,100)
    axes[i].set_xlim(0,100)
    axes[i].bar(
        X,bdf.iloc[num,1:4], 
        align="center", width=10,
        tick_label=['SHORT','MIDDLE','LONG'],
        label=bdf.iloc[num,0],
        hatch='/',
        facecolor=background_color,
        edgecolor='#2a9d8f',
        lw=1.8)
#     axes[i].set_xlabel('Range',fontsize=16)
    axes[i].set_ylabel('Accuracy',fontsize=16)
    axes[i].legend(loc='lower right',fontsize=16)
    axes[i].set_xticklabels(['SHORT','MIDDLE','LONG'],rotation=20, fontsize=12)
    
plt.savefig(f'/work/output/report/mac_passrange_main.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %%
df = pd.read_csv('/work/assets/fbref/report/brighton.csv')

# %%
df = df[[
 'Player',
 '90s_Playing Time',
 'Touches_Touches',
 'Def Pen_Touches',
 'Def 3rd_Touches',
 'Mid 3rd_Touches',
 'Att 3rd_Touches',
 'Att Pen_Touches',]]
df.head()
# Out:
#              Player  90s_Playing Time  Touches_Touches  Def Pen_Touches  \
# 0         Ben White              27.5             1583              153
# 1        Lewis Dunk              26.0             1893              301
# 2     Yves Bissouma              25.6             1562               67
# 3       Neal Maupay              22.8              779               12
# 4  Leandro Trossard              22.1             1114                6
#
#    Def 3rd_Touches  Mid 3rd_Touches  Att 3rd_Touches  Att Pen_Touches
# 0              731              750              206               20
# 1             1118              772              101               41
# 2              419              912              340                6
# 3               71              332              424              146
# 4              104              481              616               97

# %%
colors = ['#a8d5e2','#f9a620','#d1495b','#548c2f','#104911']
fig = plt.figure(
    facecolor=background_color,
    FigureClass=Waffle,
    rows=10,
    columns=10,
    figsize=(10,10),
    plots={
        '331':{
            'values':df.iloc[4,3:],
            'title':{
                'label':df.iloc[4,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
         '332':{
            'values':df.iloc[11,3:],
            'title':{
                'label':df.iloc[11,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
        '333':{
            'values':df.iloc[14,3:],
            'title':{
                'label':df.iloc[14,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
    },colors=colors)
htext.fig_text(
    s=f"The Area Brighton's Players Touch\nData: Fbref.com",
    x=.01,
    y=1.05,
    fontsize=18,
    color='#131313',
#     highlight_colors=colors,
    fontname='monospace',
    fontweight='bold',
)
htext.fig_text(
    s=f"<Def-pena> <Def-3rd> <Mid-3rd> <Att-3rd> <Att-Pena>",
    x=.01,
    y=1,
    fontsize=18,
    color='#131313',
    highlight_colors=colors,
    fontname='monospace',
    fontweight='bold',
)
image = Image.open('/work/assets/image/brighton.png')
add_image(image, fig, left=0.8, bottom=0.988, width=0.15)

plt.savefig(f'/work/output/report/area_main.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')
# Out:
# <ipython-input-13-351d9befb7c3>:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig(f'/work/output/report/area_main.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
# <Waffle size 720x720 with 4 Axes>

# %%
fig = plt.figure(
    FigureClass=Waffle, 
    rows=10,
    columns=10,
    figsize=(10,10),
    plots={
        '331':{
            'values':df.iloc[2,3:],
            'title':{
                'label':df.iloc[2,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
         '332':{
            'values':df.iloc[8,3:],
            'title':{
                'label':df.iloc[8,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
        '333':{
            'values':df.iloc[19,3:],
            'title':{
                'label':df.iloc[19,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
    },colors=colors)
        
    

plt.savefig(f'/work/output/report/area_main2.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')
# Out:
# <Waffle size 720x720 with 3 Axes>

# %%
fig = plt.figure(
    FigureClass=Waffle, 
    rows=10,
    columns=10,
    figsize=(10,10),
    plots={
        '331':{
            'values':df.iloc[4,3:],
            'title':{
                'label':df.iloc[4,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
         '332':{
            'values':df.iloc[11,3:],
            'title':{
                'label':df.iloc[11,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
        '333':{
            'values':df.iloc[14,3:],
            'title':{
                'label':df.iloc[14,0],
                'color':'black',
                'loc':'left',
                'fontsize':15,
                'fontname':'monospace'}},
        
    },colors=colors)
        
    

plt.savefig(f'/work/output/report/mac_touch3.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')
# Out:
# <Waffle size 720x720 with 3 Axes>

# %%
df0 = pd.read_csv('/work/assets/whoscored/brighton/match/2021/2021#0.csv')
df1 = pd.read_csv('/work/assets/whoscored/brighton/match/2021/2021#1.csv')
df2 = pd.read_csv('/work/assets/whoscored/brighton/match/2021/2021#2.csv')
df3 = pd.read_csv('/work/assets/whoscored/brighton/match/2021/2021#3.csv')
df4 = pd.read_csv('/work/assets/whoscored/brighton/match/2021/2021#4.csv')

id_dict = {"345319":"Alexis Mac Allister","113994":"Leandro Trossard",
           "362146":"Steven Alzate","243548":"José Izquierdo","119822":"Neal Maupay",
           "71824":"Pascal Groß","133390":"Alireza Jahanbakhsh",
           "303096":"Yves Bissouma","77429":"Davy Pröpper","110290":"Joël Veltman",
           "399378":"Jakub Moder","229654":"Percy Tau","362151":"Robert Sánchez",
           "280621":"Andi Zeqiri","21683":"Adam Lallana","33532":"Jason Steele",
           "39308":"Danny Welbeck","322036":"Ben White","82277":"Dan Burn",
           "86441":"Lewis Dunk"}

# %%
dfs = [df0,df1,df2,df3,df4]
df = pd.concat(dfs)
df = df[df['type.displayName']!='SubstitutionOn']
df_mac = df[df['playerId']==345319]

# %%
df_mac

# %%
df
# Out:
#                  Player  90s_Playing Time  Touches_Touches  Def Pen_Touches  \
# 0             Ben White              27.5             1583              153
# 1            Lewis Dunk              26.0             1893              301
# 2         Yves Bissouma              25.6             1562               67
# 3           Neal Maupay              22.8              779               12
# 4      Leandro Trossard              22.1             1114                6
# 5          Adam Webster              21.8             1535              161
# 6          Joël Veltman              20.3             1416               83
# 7           Solly March              18.6             1197               49
# 8           Pascal Groß              18.9             1314               22
# 9        Robert Sánchez              18.0              733              627
# 10             Dan Burn              16.9             1142               71
# 11         Adam Lallana              13.2              789               23
# 12          Mathew Ryan              11.0              421              338
# 13        Tariq Lamptey               9.8              635               18
# 14  Alexis Mac Allister               9.2              419                7
# 15        Danny Welbeck              10.1              249               12
# 16       Aaron Connolly               8.0              182                0
# 17        Steven Alzate               8.2              434               17
# 18  Alireza Jahanbakhsh               2.9              152                1
# 19         Davy Pröpper               2.4              116                2
# 20             Bernardo               2.3              116                3
# 21          Jakub Moder               1.1               61                0
# 22            Percy Tau               0.9               32                1
# 23          Andi Zeqiri               1.3               47                3
# 24          Reda Khadra               0.1                1                0
# 25       Jayson Molumby               0.0                1                0
# 26          Squad Total              29.0            17923             1977
# 27       Opponent Total              29.0            17190             1952
#
#     Def 3rd_Touches  Mid 3rd_Touches  Att 3rd_Touches  Att Pen_Touches
# 0               731              750              206               20
# 1              1118              772              101               41
# 2               419              912              340                6
# 3                71              332              424              146
# 4               104              481              616               97
# 5               788              745              170               27
# 6               460              642              397               32
# 7               274              468              548               59
# 8               227              634              530               57
# 9               728                5                0                0
# 10              359              553              292               36
# 11              163              375              301               54
# 12              420                2                0                0
# 13              169              278              249               33
# 14               75              184              190               31
# 15               23               94              148               52
# 16               11               77              106               35
# 17               96              225              137               16
# 18                8               56               99               20
# 19               15               74               35                4
# 20               28               40               54                5
# 21                8               28               29                5
# 22                4               18               12                4
# 23                5               13               30               11
# 24                0                0                1                1
# 25                0                1                0                0
# 26             6304             7759             5015              792
# 27             6081             7758             4331              557

# %%
df = pd.read_csv('/work/assets/fbref/report/mac_season_summary.csv')
df = df.drop(index=[5,6,7,8,9,10,11,12],columns=['Unnamed: 0'])
df = df.dropna()
df1 = pd.read_csv('/work/assets/fbref/report/mac_season_defense.csv')
df1 = df1.dropna()
df2 = pd.read_csv('/work/assets/fbref/report/mac_season_gca.csv')
df2 = df2.dropna()
df3 = pd.read_csv('/work/assets/fbref/report/mac_season_misc.csv')
df3 = df3.dropna()

df4 = pd.read_csv('/work/assets/fbref/report/mac_season_passing_types.csv')
df4 = df4.dropna()

df5 = pd.read_csv('/work/assets/fbref/report/mac_season_passing.csv')
df5 = df5.dropna()

df6 = pd.read_csv('/work/assets/fbref/report/mac_season_shot.csv')
df6 = df6.dropna()

df7 = pd.read_csv('/work/assets/fbref/report/mac_season_possession.csv')
df7 = df7.dropna()

dfs = [df,df1,df2,df3,df4,df5,df6,df7]
mdf = pd.concat(dfs)

# mdf.columns.tolist()
# df = mdf
# df['y'] = df[y]/df['90s']
# x='Press_Pressures'
# df[y]/df['90s_Playing Time']

# %%
105/3.9
# Out:
# 26.923076923076923

# %%
df1['Press_Pressures']
df['90s_Playing Time']
# Out:
# 3    3.9
# 4    9.2
# Name: 90s_Playing Time, dtype: float64

# %%
# df = pd.read_csv('/work/assets/fbref/report/brighton.csv')

# df = df.dropna()
x='Press_Pressures'
y='npxG+xA_Expected'

df1[x] = df1[x].astype(float)
df['90s_Playing Time'] = df['90s_Playing Time'].astype(float)
df['x'] = df1[x]/df['90s_Playing Time']

df[y] = df[y].astype(float)
df['y'] = df[y]/df['90s_Playing Time']


fig, ax = plt.subplots(
    facecolor=background_color, figsize=(9,6), dpi=150
)
ax.set_facecolor(background_color)
# ax.grid(color='#444444')
fig.text(x=.75,y=.05,s='Data via fbref.com',color='#131313', fontsize=7)
htext.fig_text(
    x=.15,y=.98,
    s="<Brighton><'s Scatter>",
    fontsize=16,
    color='white',
    highlight_colors=['#4361ee','#131313'],
    highlight_weights = 'bold',
#     highlight_styles = 'oblique',
    fontname='monospace'
)
# htext.fig_text(
#     x=.15,y=.93,
#     s='<Premier League | 2020/2021>',
#     fontsize=13,
#     color='white',
#     highlight_colors=['#131313'],
#     fontname='monospace'
# )
htext.fig_text(
    x=.15,y=.895,
    s=f"This Figure shows Brighton's Share of <{x[:-8]}> and <{y[:-8]}>.\nespecially <Mac>, <Lallana>, <Gross> and <Trossard> have contributed to",
    fontsize=13,
    color='#131313',
    highlight_colors=['#3a2e39','#3a2e39','#4361ee','#f72585','#6411ad','#e36414'],
    highlight_weights = 'bold',
    fontname='monospace'
    
)
ax.set_xlabel('Press Attempt',color='#131313',fontsize=11)
ax.set_ylabel('npxG+xA',color='#131313',fontsize=11)

# for idx,row in df.iterrows():
#     if row['Player'] == 'Alexis Mac Allister':
#         ax.scatter(row['x'],row['y'],s=258,c='#4361ee',marker='o',hatch=5*'/',zorder=5)
#     elif row['Player'] == 'Adam Lallana':
#         ax.scatter(row['x'],row['y'],s=258,c='#f72585',marker='o',hatch=5*'/',zorder=5)
#     elif row['Player'] == 'Leandro Trossard':
#         ax.scatter(row['x'],row['y'],s=258,c='#e36414',marker='o',hatch=5*'/',zorder=5)
#     elif row['Player'] == 'Pascal Groß':
#         ax.scatter(row['x'],row['y'],s=258,c='#6411ad',marker='o',hatch=5*'/',zorder=5)
#     ax.scatter(row['x'],row['y'], s=170 ,hatch=5*'/', alpha=.2)
    
ax.scatter(x,y)
    
# text_values = df[['x','y','Player']].values 
# texts = [
#     ax.text(val[0],val[1],val[2],
#             size=8, color=text_color, zorder=5,
#             fontfamily='monospace') for val in text_values
# ]
[text.set_path_effects([mpl.patheffects.withStroke(
    linewidth=3, foreground='#131313'
)]) for text in texts]

adjust_text(
    texts, autoalign='y',
    only_move={'points':'y', 'text':'xy'}, 
    force_objects=(0.5, 3), force_text=(0.5, 3), 
    force_points=(0.5, 7)
)

max_x = df['x'].max()
# max_x = round(max_x)
max_y = df['y'].max()
# max_y = round(max_y)

median_x = df['x'].mean()
median_y = df['y'].mean()

ax.plot(
    [median_x,median_x],[0,max_y+.03],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)
ax.plot(
    [0,max_x+.4],[median_y,median_y],
    color='#131313', ls="--", lw=1.3, alpha=0.7, zorder=1
)

image = Image.open('/work/assets/image/brighton.png')
ax_image = fig.add_axes((0.72, 0.94, 0.18, 0.18))
ax_image.axis('off')
ax_image.imshow(image)
# plt.savefig(f'/work/output/report/mac_scatter2.png', bbox_inches='tight', transparent=True, dpi=500, facecolor='#F8F8FF')

# %%
df['x']
# Out:
# 3   NaN
# 4   NaN
# 3   NaN
# 4   NaN
# 3   NaN
# 4   NaN
# 3   NaN
# 4   NaN
# 3   NaN
# 4   NaN
# 3   NaN
# 4   NaN
# 3   NaN
# 4   NaN
# 3   NaN
# 4   NaN
# Name: x, dtype: float64
