# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
from mplsoccer import Pitch, add_image, FontManager
from matplotlib.colors import LinearSegmentedColormap
from PIL import Image
import matplotlib.image as mpimg
from pywaffle import Waffle
from highlight_text import fig_text

# %%
team = "Barcelona"

cate = {0: 'MemberHome',
        1: 'MemberAway',
        2: 'MatchStats',
        3: 'SummaryHome',
        4: 'PassingHome',
        5: 'PassTypesHome',
        6: 'DefensiveHome',
        7: 'PossessionHome',
        8: 'MiscellaneousHome',
        9: 'GoalkeeperHome',
        10: 'SummaryAway',
        11: 'PassingAway',
        12: 'PassTypesAway',
        13: 'DefensiveAway', 
        14: 'PossessiongAway',
        15: 'MiscellaneousAway',
        16: 'GoalkeeperAway',
        17: 'Shots'}

category = cate[7]
categoryAway = cate[14]

sc2021 = pd.read_csv(f'/work/assets/fbref/teamStats/barcelona/match/2021/#12/{category}.csv') # sociedad
bil2021 = pd.read_csv(f"/work/assets/fbref/teamStats/barcelona/match/2021/#17/{categoryAway}.csv") # bilbao
ge2021 = pd.read_csv(f'/work/assets/fbref/teamStats/barcelona/match/2021/#31/{category}.csv') # getafe
list2021 = [sc2021,bil2021,ge2021]

sc2122 = pd.read_csv(f'/work/assets/fbref/teamStats/barcelona/match/2122/#1/{category}.csv') # sociedad 
bil2122 = pd.read_csv(f"/work/assets/fbref/teamStats/barcelona/match/2122/#2/{categoryAway}.csv") # bilbao
ge2122 = pd.read_csv(f'/work/assets/fbref/teamStats/barcelona/match/2122/#3/{category}.csv') # getafe
list2122 = [sc2122,bil2122,ge2122]

# %%
df2021 = pd.concat(list2021)
df2122 = pd.concat(list2122)
print("2021: ",df2021.columns.tolist())
print("+++++++++++++++++++")
print("2122: ",df2122.columns.tolist())
# Out:
# 2021:  ['Unnamed: 0', 'Player', '#', 'Nation', 'Pos', 'Age', 'Min', 'Touches_Touches', 'Def Pen_Touches', 'Def 3rd_Touches', 'Mid 3rd_Touches', 'Att 3rd_Touches', 'Att Pen_Touches', 'Live_Touches', 'Succ_Dribbles', 'Att_Dribbles', 'Succ%_Dribbles', '#Pl_Dribbles', 'Megs_Dribbles', 'Carries_Carries', 'TotDist_Carries', 'PrgDist_Carries', 'Prog_Carries', '1/3_Carries', 'CPA_Carries', 'Mis_Carries', 'Dis_Carries', 'Targ_Receiving', 'Rec_Receiving', 'Rec%_Receiving', 'Prog_Receiving']
# +++++++++++++++++++
# 2122:  ['Unnamed: 0', 'Player', '#', 'Nation', 'Pos', 'Age', 'Min', 'Touches_Touches', 'Def Pen_Touches', 'Def 3rd_Touches', 'Mid 3rd_Touches', 'Att 3rd_Touches', 'Att Pen_Touches', 'Live_Touches', 'Succ_Dribbles', 'Att_Dribbles', 'Succ%_Dribbles', '#Pl_Dribbles', 'Megs_Dribbles', 'Carries_Carries', 'TotDist_Carries', 'PrgDist_Carries', 'Prog_Carries', '1/3_Carries', 'CPA_Carries', 'Mis_Carries', 'Dis_Carries', 'Targ_Receiving', 'Rec_Receiving', 'Rec%_Receiving', 'Prog_Receiving']

# %%
df2021 = df2021[(df2021["Player"]!="15 Players")&(df2021["Player"]!="13 Players")]
df2122 = df2122[(df2122["Player"]!="15 Players")&(df2122["Player"]!="13 Players")]

df2021.head()
# df2122.head()
# Out:
#    Unnamed: 0              Player     #   Nation Pos     Age  Min  \
# 0           0        Lionel Messi  10.0  ar  ARG  FW  33-175   90
# 1           1  Martin Braithwaite   9.0  dk  DEN  LW  29-194   90
# 2           2   Antoine Griezmann   7.0  fr  FRA  RW  29-270   65
# 3           3   Francisco Trincão  17.0  pt  POR  RW  20-353   25
# 4           4               Pedri  16.0  es  ESP  AM  18-021   73
#
#    Touches_Touches  Def Pen_Touches  Def 3rd_Touches  ...  PrgDist_Carries  \
# 0               83                0                9  ...              278
# 1               42                1                5  ...               81
# 2               40                0                2  ...               79
# 3               17                2                9  ...               59
# 4               47                1                6  ...              117
#
#    Prog_Carries  1/3_Carries  CPA_Carries  Mis_Carries  Dis_Carries  \
# 0            15            5            2            2            2
# 1             4            0            1            0            3
# 2             3            1            0            1            0
# 3             0            0            0            0            1
# 4             8            2            0            2            0
#
#    Targ_Receiving  Rec_Receiving  Rec%_Receiving  Prog_Receiving
# 0              84             70            83.3               5
# 1              53             37            69.8              11
# 2              43             33            76.7               6
# 3              13             11            84.6               2
# 4              51             37            72.5               4
#
# [5 rows x 31 columns]

# %%
sortCol = "Touches_Touches"
df2021 = df2021.sort_values(by=[sortCol], ascending=False)
df2021.head()
# Out:
#     Unnamed: 0           Player     #   Nation    Pos     Age  Min  \
# 12          12   Óscar Mingueza  28.0  es  ESP     CB  21-344   74
# 6            6    Sergi Roberto  20.0  es  ESP     WB  29-074   63
# 4            4  Sergio Busquets   5.0  es  ESP     DM  32-280   90
# 3            3  Frenkie de Jong  21.0  nl  NED  CB,CM  23-345   90
# 7            7       Jordi Alba  18.0  es  ESP     LB  31-291   90
#
#     Touches_Touches  Def Pen_Touches  Def 3rd_Touches  ...  PrgDist_Carries  \
# 12              128                6               41  ...              234
# 6               113                2               17  ...              122
# 4               113                3               21  ...              125
# 3               107                2               32  ...              141
# 7               107                1               26  ...              160
#
#     Prog_Carries  1/3_Carries  CPA_Carries  Mis_Carries  Dis_Carries  \
# 12             8            1            0            0            0
# 6              6            1            0            0            0
# 4              8            2            0            0            0
# 3              3            3            0            0            2
# 7              9            4            1            0            1
#
#     Targ_Receiving  Rec_Receiving  Rec%_Receiving  Prog_Receiving
# 12             116            114            98.3               1
# 6               90             87            96.7               8
# 4              101             94            93.1               0
# 3               98             89            90.8               3
# 7               83             82            98.8              12
#
# [5 rows x 31 columns]

# %%
df2021.drop(columns=["Unnamed: 0"],inplace=True)
df2122.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df2021 = df2021[["Player","Def Pen_Touches","Def 3rd_Touches","Mid 3rd_Touches","Att 3rd_Touches","Att Pen_Touches"]]
df2021.reset_index(inplace=True,drop=True)
df2122 = df2122[["Player","Def Pen_Touches","Def 3rd_Touches","Mid 3rd_Touches","Att 3rd_Touches","Att Pen_Touches"]]
df2122.reset_index(inplace=True,drop=True)

# %%
img = mpimg.imread('/work/assets/image/barcelona.png')
image = Image.open('/work/assets/image/barcelona.png')

def plot_waffle(df,opponent):
    df = df[["Player","Def Pen_Touches","Def 3rd_Touches","Mid 3rd_Touches","Att 3rd_Touches","Att Pen_Touches"]]    
    df.reset_index(inplace=True,drop=True)
    labelList = df.loc[0:,"Player"]
    print(labelList)
    
    fig = plt.figure(
        FigureClass=Waffle, 
        rows=10,
        columns=10,
        figsize=(10,10),
        plots={
            '341':{
                'values':df.iloc[1,1:],
                'title':{
                    'label':labelList[1],
                    'color':'white',
                    'loc':'left',
                    'fontsize':15},          
            },
            '342':{
                'values':df.iloc[2,1:],
                'title':{
                    'label':labelList[2],
                    'color':'white',
                    'loc':'left',
                    'fontsize':15},
            },
            '343':{
                'values':df.iloc[3,1:],
                'title':{
                    'label':labelList[3],
                    'color':'white',
                    'loc':'left',
                    'fontsize':15},
            },
            '344':{
                'values':df.iloc[4,1:],
                'title':{
                    'label':labelList[4],
                    'color':'white',
                    'loc':'left',
                    'fontsize':15},            
            },
            '345':{
                'values':df.iloc[5,1:],
                'title':{
                    'label':labelList[5],
                    'color':'white',
                    'loc':'left',
                    'fontsize':15},            
            },
            '346':{
                'values':df.iloc[6,1:],
                'title':{
                    'label':labelList[6],
                    'color':'white',
                    'loc':'left',
                    'fontsize':15},            
            },
            '347':{
                'values':df.iloc[7,1:],
                'title':{
                    'label':labelList[7],
                    'color':'white',
                    'loc':'left',
                    'fontsize':15},            
            },
            '348':{
                'values':df.iloc[8,1:],
                'title':{
                    'label':labelList[8],
                    'color':'white',
                    'loc':'left',
                    'fontsize':15},            
            },
        },
        colors=('#7f5af0', '#4fc4cf', '#2cb67d', '#ff8906', '#ef4565')
    )
    add_image(image, fig, left=0.8, bottom=0.988, width=0.15)

    fig.suptitle(t=f"{team} Player Touch Area (vs {opponent})",
                 x=0.314,y=1.1,color="#fffffe",fontsize=21, fontname="cmb10")

    fig.text(x=0.03,y=.96,s="data via Fbref",color="#fffffe",fontsize=16, fontname="cmb10")

    fig_text(
        s=f"<Def-pena> <Def-3rd> <Mid-3rd> <Att-3rd> <Att-pena>",
        x=.03,
        y=.99,
        fontsize=19,
        fontname="cmb10",
        color='#fffffe',
        highlight_colors=['#7f5af0', '#4fc4cf', '#2cb67d', '#ff8906', '#ef4565']

    )
    fig.patch.set_facecolor('#131313')

# %%
plot_waffle(df2021,opponent="aa")
# Out:
# 0            Óscar Mingueza
# 1             Sergi Roberto
# 2           Sergio Busquets
# 3           Frenkie de Jong
# 4                Jordi Alba
# 5           Sergio Busquets
# 6                Jordi Alba
# 7              Lionel Messi
# 8              Lionel Messi
# 9           Clément Lenglet
# 10          Frenkie de Jong
# 11                    Pedri
# 12             Gerard Piqué
# 13             Lionel Messi
# 14                    Pedri
# 15          Clément Lenglet
# 16               Jordi Alba
# 17             Sergiño Dest
# 18            Ronald Araújo
# 19          Frenkie de Jong
# 20          Ousmane Dembélé
# 21        Antoine Griezmann
# 22           Óscar Mingueza
# 23                    Ilaix
# 24                    Pedri
# 25          Sergio Busquets
# 26            Ronald Araújo
# 27             Sergiño Dest
# 28        Antoine Griezmann
# 29    Marc-André ter Stegen
# 30       Martin Braithwaite
# 31        Antoine Griezmann
# 32            Ronald Araújo
# 33    Marc-André ter Stegen
# 34    Marc-André ter Stegen
# 35            Samuel Umtiti
# 36        Francisco Trincão
# 37        Francisco Trincão
# 38             Carles Aleñá
# 39           Miralem Pjanić
# 40           Óscar Mingueza
# 41       Martin Braithwaite
# 42          Clément Lenglet
# Name: Player, dtype: object
# <Waffle size 720x720 with 9 Axes>

# %%
df2021.groupby(by="Player").sum()
# Out:
#                        Def Pen_Touches  Def 3rd_Touches  Mid 3rd_Touches  \
# Player
# Antoine Griezmann                    3               18               53
# Carles Aleñá                         0                2                9
# Clément Lenglet                     18               71               98
# Francisco Trincão                    2               11               14
# Frenkie de Jong                      6               68              150
# Gerard Piqué                         7               33               50
# Ilaix                                0                5               35
# Jordi Alba                           2               69              113
# Lionel Messi                         0               14              132
# Marc-André ter Stegen              100              112                0
# Martin Braithwaite                   2               10               16
# Miralem Pjanić                       2                5                6
# Ousmane Dembélé                      0                5               26
# Pedri                                2               26              108
# Ronald Araújo                       31               88               69
# Samuel Umtiti                        2               12               10
# Sergi Roberto                        2               17               51
# Sergio Busquets                      8               61              166
# Sergiño Dest                         6               39               45
# Óscar Mingueza                      15               71              117
#
#                        Att 3rd_Touches  Att Pen_Touches
# Player
# Antoine Griezmann                   75               21
# Carles Aleñá                         3                1
# Clément Lenglet                      4                0
# Francisco Trincão                   15                2
# Frenkie de Jong                     57                9
# Gerard Piqué                         0                0
# Ilaix                               11                2
# Jordi Alba                          92               11
# Lionel Messi                       121               17
# Marc-André ter Stegen                0                0
# Martin Braithwaite                  26                6
# Miralem Pjanić                       1                0
# Ousmane Dembélé                     38                6
# Pedri                               74                9
# Ronald Araújo                        3                2
# Samuel Umtiti                        0                0
# Sergi Roberto                       50                2
# Sergio Busquets                     26                0
# Sergiño Dest                        34                5
# Óscar Mingueza                       8                1

# %%
df2122.groupby(by="Player").sum()
# Out:
#                        Def Pen_Touches  Def 3rd_Touches  Mid 3rd_Touches  \
# Player
# 16 Players                          85              221              362
# Antoine Griezmann                    5               24               85
# Clément Lenglet                      4               45               71
# Emerson                              1               20               50
# Eric García                         31               85               76
# Frenkie de Jong                      7               47              150
# Gavi Paez                            1                3               11
# Gerard Piqué                        24               54               59
# Jordi Alba                          12               80              125
# Marc-André ter Stegen               42               49                1
# Martin Braithwaite                   4               10               42
# Memphis Depay                        2                8               74
# Neto                                96              105                0
# Nicolás González                     0                5               16
# Pedri                                2               15               59
# Ronald Araújo                       22               89               73
# Sergi Roberto                        2               18               65
# Sergio Busquets                     13               73              162
# Sergiño Dest                         3               44               61
# Yusuf Demir                          0                2                7
# Óscar Mingueza                       0                3                3
#
#                        Att 3rd_Touches  Att Pen_Touches
# Player
# 16 Players                         176               31
# Antoine Griezmann                   47                8
# Clément Lenglet                      1                0
# Emerson                             16                1
# Eric García                          3                0
# Frenkie de Jong                     46                8
# Gavi Paez                            9                2
# Gerard Piqué                         1                1
# Jordi Alba                          92               13
# Marc-André ter Stegen                0                0
# Martin Braithwaite                  38               15
# Memphis Depay                       90               17
# Neto                                 0                0
# Nicolás González                     9                1
# Pedri                               35                1
# Ronald Araújo                        0                0
# Sergi Roberto                       18                4
# Sergio Busquets                     19                0
# Sergiño Dest                        38                8
# Yusuf Demir                          8                2
# Óscar Mingueza                       2                0
