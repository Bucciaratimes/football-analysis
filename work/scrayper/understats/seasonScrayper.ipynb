# %%
import json
import os
import pickle
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# https://github.com/douglasbc/scraping-understat-dataset
CWD = os.getcwd()
DIR = os.path.join(CWD,"datasets")
DIR_TEAMS = os.path.join(CWD,"scraping", "teams_set")

BASE_LEAGUE_URL = "https://understat.com/league/"


def scrape_script_tags_season(season):
    """
    Takes a string with a league/season combination, e.g., "EPL_2020"
    to define a URL to be scraped.
    Returns a ResultSet object, class implemented by BeautifulSoup, with all
    the script tags in the URL.
    """
    URL = BASE_LEAGUE_URL + season
    response = requests.get(URL)
    soup = BeautifulSoup(response.content, "lxml")
    soup_scripts = soup.find_all("script")
    return soup_scripts


def generate_players_dict(season):
    """
    Takes a ResultSet and a string with a league/season combination.
    Returns a list of dictionaries with data on every player for the season.
    """
    soup_scripts = scrape_script_tags_season(season)

    script = soup_scripts[3].string

    start_index = script.index("('")+2
    end_index = script.index("')")
    json_string = script[start_index:end_index]
    json_string = json_string.encode("utf8").decode("unicode_escape")
    players_dict = json.loads(json_string)
    return players_dict


def generate_players_csv(first_year, last_year):
    """
    Takes initial and final years so that the datasets generated with
    generate_players_dict function can de exported to .csv files.
    """
    leagues = ["EPL", "La_liga", "Bundesliga", "Serie_A", "Ligue_1", "RFPL"]
    years = list(range(first_year,last_year + 1))

    for league in leagues:
        for year in years:
            season = league + "/" + str(year)

            league_lower = league.lower()
            season_years = str(year)[-2:] + "-" + str(year+1)[-2:]

            output_file = "players_" + league_lower + "_" + season_years + ".csv"
            output_dir = os.path.join(DIR, league_lower)
            os.makedirs(output_dir, exist_ok=True)

            file_path = os.path.join(output_dir, output_file)

            players_dict = generate_players_dict(season)
            players_df = pd.DataFrame.from_dict(players_dict)
            players_df.to_csv(file_path,index=False)


def generate_set_of_teams(first_year, last_year):
    """
    Scrapes the names of the teams for every league/season combination. The
    data is aggregated, resulting in a set for every league. Using pickle the
    sets are exported to be used in the match_scraper.py module.
    """
    leagues = ["EPL", "La_liga", "Bundesliga", "Serie_A", "Ligue_1", "RFPL"]
    years = list(range(first_year,last_year + 1))


    for league in leagues:
        teams_list = []

        for year in years:
            season = league + "/" + str(year)

            soup_scripts = scrape_script_tags_season(season)
            script = soup_scripts[2].string

            start_index = script.index("('")+2
            end_index = script.index("')")
            json_string = script[start_index:end_index]
            json_string = json_string.encode("utf8").decode("unicode_escape")
            script_dict = json.loads(json_string)

            df = pd.DataFrame.from_dict(script_dict).T
            teams = df["title"].tolist()
            teams_list.extend(teams)

        teams_set = set(teams_list)

        output_file = league + "_teams.txt"
        os.makedirs(DIR_TEAMS, exist_ok=True)

        file_path = os.path.join(DIR_TEAMS, output_file)
        print(file_path)

        with open(file_path, "wb") as fp:
            pickle.dump(teams_set, fp)

# %%
generate_players_csv(2021,2022)

# %%
generate_set_of_teams(2020,2021)

# %%
scrape_script_tags_season("2021")
# Out:
# []

# %%
# generate_players_dict("/La_liga")
# Out:
# [{'id': '227',
#   'player_name': 'Robert Lewandowski',
#   'games': '14',
#   'time': '1077',
#   'goals': '13',
#   'xG': '11.34012384712696',
#   'assists': '4',
#   'xA': '2.2946582287549973',
#   'shots': '51',
#   'key_passes': '15',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Barcelona',
#   'npg': '13',
#   'npxG': '10.596846297383308',
#   'xGChain': '17.164135061204433',
#   'xGBuildup': '4.930684370920062'},
#  {'id': '2543',
#   'player_name': 'Borja Iglesias',
#   'games': '13',
#   'time': '992',
#   'goals': '8',
#   'xG': '6.965447053313255',
#   'assists': '2',
#   'xA': '1.780620351433754',
#   'shots': '30',
#   'key_passes': '9',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Real Betis',
#   'npg': '5',
#   'npxG': '4.7357421070337296',
#   'xGChain': '7.083343863487244',
#   'xGBuildup': '1.2788673862814903'},
#  {'id': '9002',
#   'player_name': 'Vedat Muriqi',
#   'games': '12',
#   'time': '1060',
#   'goals': '8',
#   'xG': '7.412161931395531',
#   'assists': '1',
#   'xA': '0.9085313910618424',
#   'shots': '36',
#   'key_passes': '12',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F',
#   'team_title': 'Mallorca',
#   'npg': '6',
#   'npxG': '5.182329043745995',
#   'xGChain': '6.107765324413776',
#   'xGBuildup': '0.7253125458955765'},
#  {'id': '866',
#   'player_name': 'Joselu',
#   'games': '14',
#   'time': '1260',
#   'goals': '7',
#   'xG': '6.742516964673996',
#   'assists': '1',
#   'xA': '0.7607010416686535',
#   'shots': '39',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Espanyol',
#   'npg': '5',
#   'npxG': '5.255961716175079',
#   'xGChain': '6.535690538585186',
#   'xGBuildup': '1.036329218186438'},
#  {'id': '2290',
#   'player_name': 'Iago Aspas',
#   'games': '14',
#   'time': '1116',
#   'goals': '7',
#   'xG': '3.5198958069086075',
#   'assists': '2',
#   'xA': '2.5705330315977335',
#   'shots': '28',
#   'key_passes': '35',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Celta Vigo',
#   'npg': '6',
#   'npxG': '2.033340573310852',
#   'xGChain': '5.400818876922131',
#   'xGBuildup': '2.2571407295763493'},
#  {'id': '6227',
#   'player_name': 'Brais Méndez',
#   'games': '14',
#   'time': '1133',
#   'goals': '6',
#   'xG': '3.8963050581514835',
#   'assists': '2',
#   'xA': '2.048058096319437',
#   'shots': '30',
#   'key_passes': '18',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Sociedad',
#   'npg': '6',
#   'npxG': '3.8963050581514835',
#   'xGChain': '7.517665512859821',
#   'xGBuildup': '3.9507678374648094'},
#  {'id': '6241',
#   'player_name': 'Federico Valverde',
#   'games': '14',
#   'time': '1105',
#   'goals': '6',
#   'xG': '1.7493886686861515',
#   'assists': '2',
#   'xA': '3.051829993724823',
#   'shots': '31',
#   'key_passes': '24',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Madrid',
#   'npg': '6',
#   'npxG': '1.7493886686861515',
#   'xGChain': '9.29616791754961',
#   'xGBuildup': '6.238646414130926'},
#  {'id': '6955',
#   'player_name': 'Ezequiel Ávila',
#   'games': '13',
#   'time': '869',
#   'goals': '6',
#   'xG': '4.300586415454745',
#   'assists': '1',
#   'xA': '1.8040775377303362',
#   'shots': '30',
#   'key_passes': '13',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Osasuna',
#   'npg': '4',
#   'npxG': '2.0707535725086927',
#   'xGChain': '4.352283105254173',
#   'xGBuildup': '0.9900697432458401'},
#  {'id': '7008',
#   'player_name': 'Vinícius Júnior',
#   'games': '14',
#   'time': '1243',
#   'goals': '6',
#   'xG': '6.200758710503578',
#   'assists': '3',
#   'xA': '4.300311453640461',
#   'shots': '36',
#   'key_passes': '26',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Real Madrid',
#   'npg': '6',
#   'npxG': '6.200758710503578',
#   'xGChain': '13.496214181184769',
#   'xGBuildup': '4.3887393325567245'},
#  {'id': '1804',
#   'player_name': 'Álvaro Morata',
#   'games': '14',
#   'time': '877',
#   'goals': '5',
#   'xG': '4.80132358148694',
#   'assists': '1',
#   'xA': '0.7031529787927866',
#   'shots': '30',
#   'key_passes': '8',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Atletico Madrid',
#   'npg': '5',
#   'npxG': '4.80132358148694',
#   'xGChain': '3.9586819298565388',
#   'xGBuildup': '0.38577783294022083'},
#  {'id': '2270',
#   'player_name': 'Antoine Griezmann',
#   'games': '14',
#   'time': '756',
#   'goals': '5',
#   'xG': '2.3550236355513334',
#   'assists': '3',
#   'xA': '3.5099896863102913',
#   'shots': '26',
#   'key_passes': '24',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '5',
#   'npxG': '2.3550236355513334',
#   'xGChain': '6.183764688670635',
#   'xGBuildup': '2.1903156396001577'},
#  {'id': '2370',
#   'player_name': 'Karim Benzema',
#   'games': '7',
#   'time': '629',
#   'goals': '5',
#   'xG': '7.828226819634438',
#   'assists': '1',
#   'xA': '1.0508344769477844',
#   'shots': '34',
#   'key_passes': '15',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Real Madrid',
#   'npg': '4',
#   'npxG': '6.3416715413331985',
#   'xGChain': '8.153824746608734',
#   'xGBuildup': '2.8006817623972893'},
#  {'id': '2399',
#   'player_name': 'Iñaki Williams',
#   'games': '14',
#   'time': '1173',
#   'goals': '5',
#   'xG': '5.927120339125395',
#   'assists': '1',
#   'xA': '2.7635279297828674',
#   'shots': '34',
#   'key_passes': '15',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Athletic Club',
#   'npg': '5',
#   'npxG': '5.183842729777098',
#   'xGChain': '9.197747450321913',
#   'xGBuildup': '1.9849189054220915'},
#  {'id': '5095',
#   'player_name': 'Sergio León',
#   'games': '13',
#   'time': '627',
#   'goals': '5',
#   'xG': '3.4052009508013725',
#   'assists': '1',
#   'xA': '1.069292058236897',
#   'shots': '16',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Real Valladolid',
#   'npg': '4',
#   'npxG': '1.918645717203617',
#   'xGChain': '3.0194002017378807',
#   'xGBuildup': '0.09807412326335907'},
#  {'id': '7020',
#   'player_name': 'Gorka Guruzeta',
#   'games': '7',
#   'time': '181',
#   'goals': '5',
#   'xG': '2.58965908177197',
#   'assists': '0',
#   'xA': '0.1869082897901535',
#   'shots': '13',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Athletic Club',
#   'npg': '5',
#   'npxG': '2.58965908177197',
#   'xGChain': '3.286877067759633',
#   'xGBuildup': '0.9154467303305864'},
#  {'id': '1709',
#   'player_name': 'Cristhian Stuani',
#   'games': '10',
#   'time': '403',
#   'goals': '4',
#   'xG': '4.183144629001617',
#   'assists': '0',
#   'xA': '0.3186374679207802',
#   'shots': '13',
#   'key_passes': '4',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Girona',
#   'npg': '1',
#   'npxG': '1.2100342363119125',
#   'xGChain': '1.2511196788400412',
#   'xGBuildup': '0.10625908337533474'},
#  {'id': '3226',
#   'player_name': 'Ousmane Dembélé',
#   'games': '14',
#   'time': '895',
#   'goals': '4',
#   'xG': '2.735863910987973',
#   'assists': '5',
#   'xA': '4.508561514317989',
#   'shots': '30',
#   'key_passes': '31',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Barcelona',
#   'npg': '4',
#   'npxG': '2.735863910987973',
#   'xGChain': '11.009383082389832',
#   'xGBuildup': '5.088992141187191'},
#  {'id': '3294',
#   'player_name': 'Edinson Cavani',
#   'games': '7',
#   'time': '450',
#   'goals': '4',
#   'xG': '4.216762378811836',
#   'assists': '1',
#   'xA': '0.5108960159122944',
#   'shots': '14',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Valencia',
#   'npg': '2',
#   'npxG': '1.9869294855743647',
#   'xGChain': '2.7391395196318626',
#   'xGBuildup': '0.38089357409626245'},
#  {'id': '6219',
#   'player_name': 'Enes Ünal',
#   'games': '14',
#   'time': '1236',
#   'goals': '4',
#   'xG': '3.310837228782475',
#   'assists': '2',
#   'xA': '1.2050160765647888',
#   'shots': '31',
#   'key_passes': '10',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Getafe',
#   'npg': '4',
#   'npxG': '2.567559619434178',
#   'xGChain': '3.614147400483489',
#   'xGBuildup': '0.6056977696716785'},
#  {'id': '6531',
#   'player_name': 'Alexander Sørloth',
#   'games': '10',
#   'time': '836',
#   'goals': '4',
#   'xG': '5.840085305273533',
#   'assists': '1',
#   'xA': '1.247129587456584',
#   'shots': '24',
#   'key_passes': '12',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Real Sociedad',
#   'npg': '4',
#   'npxG': '5.840085305273533',
#   'xGChain': '8.732353707775474',
#   'xGBuildup': '1.8222123458981514'},
#  {'id': '8015',
#   'player_name': 'Rodrygo',
#   'games': '12',
#   'time': '921',
#   'goals': '4',
#   'xG': '6.514320384711027',
#   'assists': '4',
#   'xA': '3.8446141434833407',
#   'shots': '39',
#   'key_passes': '17',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Real Madrid',
#   'npg': '3',
#   'npxG': '5.77104277536273',
#   'xGChain': '12.208367705345154',
#   'xGBuildup': '4.207139372825623'},
#  {'id': '8417',
#   'player_name': 'Álex Baena',
#   'games': '13',
#   'time': '611',
#   'goals': '4',
#   'xG': '1.9503511395305395',
#   'assists': '0',
#   'xA': '1.4816814288496971',
#   'shots': '18',
#   'key_passes': '11',
#   'yellow_cards': '4',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Villarreal',
#   'npg': '4',
#   'npxG': '1.9503511395305395',
#   'xGChain': '4.501959804445505',
#   'xGBuildup': '1.7405119463801384'},
#  {'id': '644',
#   'player_name': 'Erik Lamela',
#   'games': '13',
#   'time': '958',
#   'goals': '3',
#   'xG': '2.958358551375568',
#   'assists': '0',
#   'xA': '0.909440828487277',
#   'shots': '23',
#   'key_passes': '14',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Sevilla',
#   'npg': '3',
#   'npxG': '2.958358551375568',
#   'xGChain': '4.732292145490646',
#   'xGBuildup': '2.0799779538065195'},
#  {'id': '1450',
#   'player_name': 'Umar Sadiq',
#   'games': '5',
#   'time': '328',
#   'goals': '3',
#   'xG': '1.863716371357441',
#   'assists': '0',
#   'xA': '0.3351796930655837',
#   'shots': '8',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Almeria,Real Sociedad',
#   'npg': '3',
#   'npxG': '1.863716371357441',
#   'xGChain': '2.0354344211518764',
#   'xGBuildup': '0.05808890983462334'},
#  {'id': '2250',
#   'player_name': 'Luka Modric',
#   'games': '13',
#   'time': '945',
#   'goals': '3',
#   'xG': '2.7658922374248505',
#   'assists': '2',
#   'xA': '2.562127936631441',
#   'shots': '18',
#   'key_passes': '21',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Madrid',
#   'npg': '2',
#   'npxG': '2.0226146280765533',
#   'xGChain': '9.45221957191825',
#   'xGBuildup': '6.778820242732763'},
#  {'id': '2275',
#   'player_name': 'Ángel Correa',
#   'games': '14',
#   'time': '496',
#   'goals': '3',
#   'xG': '3.0641407556831837',
#   'assists': '0',
#   'xA': '1.513204038143158',
#   'shots': '20',
#   'key_passes': '9',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '3',
#   'npxG': '3.0641407556831837',
#   'xGChain': '3.9894510358572006',
#   'xGBuildup': '0.589682636782527'},
#  {'id': '2424',
#   'player_name': 'Óliver Torres',
#   'games': '12',
#   'time': '894',
#   'goals': '3',
#   'xG': '0.8565335553139448',
#   'assists': '0',
#   'xA': '0.7202519401907921',
#   'shots': '7',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Sevilla',
#   'npg': '3',
#   'npxG': '0.8565335553139448',
#   'xGChain': '3.4120762571692467',
#   'xGBuildup': '2.148745248094201'},
#  {'id': '3211',
#   'player_name': 'Martin Braithwaite',
#   'games': '9',
#   'time': '721',
#   'goals': '3',
#   'xG': '2.85871734470129',
#   'assists': '1',
#   'xA': '0.48774263449013233',
#   'shots': '17',
#   'key_passes': '4',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'F M',
#   'team_title': 'Espanyol',
#   'npg': '3',
#   'npxG': '2.85871734470129',
#   'xGChain': '3.499455524608493',
#   'xGBuildup': '0.4911974538117647'},
#  {'id': '4175',
#   'player_name': 'Pere Milla',
#   'games': '13',
#   'time': '799',
#   'goals': '3',
#   'xG': '1.4400906302034855',
#   'assists': '1',
#   'xA': '0.7468690127134323',
#   'shots': '11',
#   'key_passes': '8',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Elche',
#   'npg': '2',
#   'npxG': '0.6968130208551884',
#   'xGChain': '1.717808909714222',
#   'xGBuildup': '0.5557489320635796'},
#  {'id': '5073',
#   'player_name': 'Florian Lejeune',
#   'games': '12',
#   'time': '954',
#   'goals': '3',
#   'xG': '1.1708223121240735',
#   'assists': '0',
#   'xA': '0.12903371453285217',
#   'shots': '14',
#   'key_passes': '4',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'D',
#   'team_title': 'Rayo Vallecano',
#   'npg': '3',
#   'npxG': '1.1708223121240735',
#   'xGChain': '1.3297324860468507',
#   'xGBuildup': '1.283976074308157'},
#  {'id': '5091',
#   'player_name': 'Alex Berenguer',
#   'games': '13',
#   'time': '1042',
#   'goals': '3',
#   'xG': '3.55587987229228',
#   'assists': '1',
#   'xA': '3.187593705020845',
#   'shots': '26',
#   'key_passes': '24',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Athletic Club',
#   'npg': '3',
#   'npxG': '3.55587987229228',
#   'xGChain': '7.31364032253623',
#   'xGBuildup': '2.704477682709694'},
#  {'id': '7071',
#   'player_name': 'Álvaro García',
#   'games': '13',
#   'time': '1115',
#   'goals': '3',
#   'xG': '1.5425447886809707',
#   'assists': '1',
#   'xA': '1.4494546353816986',
#   'shots': '18',
#   'key_passes': '13',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Rayo Vallecano',
#   'npg': '3',
#   'npxG': '1.5425447886809707',
#   'xGChain': '3.388200145214796',
#   'xGBuildup': '1.4555983804166317'},
#  {'id': '7779',
#   'player_name': 'Oihan Sancet',
#   'games': '14',
#   'time': '970',
#   'goals': '3',
#   'xG': '1.985035634599626',
#   'assists': '0',
#   'xA': '1.4346404522657394',
#   'shots': '17',
#   'key_passes': '14',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Athletic Club',
#   'npg': '2',
#   'npxG': '1.241758025251329',
#   'xGChain': '6.077304862439632',
#   'xGBuildup': '4.037861507385969'},
#  {'id': '7829',
#   'player_name': 'Eder Militão',
#   'games': '12',
#   'time': '909',
#   'goals': '3',
#   'xG': '1.2043620748445392',
#   'assists': '0',
#   'xA': '0.13198576122522354',
#   'shots': '8',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Real Madrid',
#   'npg': '3',
#   'npxG': '1.2043620748445392',
#   'xGChain': '5.175070717930794',
#   'xGBuildup': '5.0693004578351974'},
#  {'id': '7967',
#   'player_name': 'Anssumane Fati',
#   'games': '14',
#   'time': '431',
#   'goals': '3',
#   'xG': '6.185212688520551',
#   'assists': '3',
#   'xA': '0.8517752606421709',
#   'shots': '29',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Barcelona',
#   'npg': '3',
#   'npxG': '6.185212688520551',
#   'xGChain': '8.325370594859123',
#   'xGBuildup': '2.435797266662121'},
#  {'id': '8002',
#   'player_name': 'Rodrigo Riquelme',
#   'games': '13',
#   'time': '813',
#   'goals': '3',
#   'xG': '1.4749425817281008',
#   'assists': '0',
#   'xA': '0.5529962508007884',
#   'shots': '22',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Girona',
#   'npg': '3',
#   'npxG': '1.4749425817281008',
#   'xGChain': '3.8226716443896294',
#   'xGBuildup': '1.9766093529760838'},
#  {'id': '8294',
#   'player_name': 'El Bilal Touré',
#   'games': '8',
#   'time': '583',
#   'goals': '3',
#   'xG': '2.5990449115633965',
#   'assists': '1',
#   'xA': '0.17819339781999588',
#   'shots': '12',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Almeria',
#   'npg': '3',
#   'npxG': '2.5990449115633965',
#   'xGChain': '3.068363480269909',
#   'xGBuildup': '0.5209256131201982'},
#  {'id': '8713',
#   'player_name': 'Gabriel Veiga',
#   'games': '13',
#   'time': '581',
#   'goals': '3',
#   'xG': '0.5071313269436359',
#   'assists': '1',
#   'xA': '0.20440023764967918',
#   'shots': '15',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Celta Vigo',
#   'npg': '3',
#   'npxG': '0.5071313269436359',
#   'xGChain': '1.620641928166151',
#   'xGBuildup': '1.0333298202604055'},
#  {'id': '8935',
#   'player_name': 'Pedri',
#   'games': '14',
#   'time': '1040',
#   'goals': '3',
#   'xG': '1.714216846972704',
#   'assists': '0',
#   'xA': '2.786761488765478',
#   'shots': '10',
#   'key_passes': '18',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Barcelona',
#   'npg': '3',
#   'npxG': '1.714216846972704',
#   'xGChain': '14.539203584194183',
#   'xGBuildup': '12.150636062026024'},
#  {'id': '9211',
#   'player_name': 'Nico Williams',
#   'games': '14',
#   'time': '1099',
#   'goals': '3',
#   'xG': '2.7914324067533016',
#   'assists': '3',
#   'xA': '2.2644778341054916',
#   'shots': '24',
#   'key_passes': '19',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Athletic Club',
#   'npg': '3',
#   'npxG': '2.7914324067533016',
#   'xGChain': '8.224463004618883',
#   'xGBuildup': '3.3007040917873383'},
#  {'id': '9812',
#   'player_name': 'Isi Palazón',
#   'games': '13',
#   'time': '1021',
#   'goals': '3',
#   'xG': '2.2594792041927576',
#   'assists': '3',
#   'xA': '1.562210748437792',
#   'shots': '30',
#   'key_passes': '15',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '2',
#   'npxG': '1.5162016246467829',
#   'xGChain': '2.765202483162284',
#   'xGBuildup': '1.5939661478623748'},
#  {'id': '10948',
#   'player_name': 'Valentín Castellanos',
#   'games': '14',
#   'time': '1144',
#   'goals': '3',
#   'xG': '3.2237243205308914',
#   'assists': '0',
#   'xA': '0.5836395230144262',
#   'shots': '29',
#   'key_passes': '9',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Girona',
#   'npg': '3',
#   'npxG': '3.2237243205308914',
#   'xGChain': '4.231642499566078',
#   'xGBuildup': '1.077081760391593'},
#  {'id': '696',
#   'player_name': 'Falcao',
#   'games': '12',
#   'time': '377',
#   'goals': '2',
#   'xG': '2.527351113036275',
#   'assists': '0',
#   'xA': '0.04875889793038368',
#   'shots': '13',
#   'key_passes': '1',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '1',
#   'npxG': '1.7840734738856554',
#   'xGChain': '1.997648125514388',
#   'xGBuildup': '0.6166673414409161'},
#  {'id': '897',
#   'player_name': 'Juanmi',
#   'games': '4',
#   'time': '320',
#   'goals': '2',
#   'xG': '2.1461332701146603',
#   'assists': '0',
#   'xA': '0.030411072075366974',
#   'shots': '7',
#   'key_passes': '1',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Real Betis',
#   'npg': '2',
#   'npxG': '2.1461332701146603',
#   'xGChain': '2.4695802442729473',
#   'xGBuildup': '0.29303596913814545'},
#  {'id': '1700',
#   'player_name': 'Lucas Pérez',
#   'games': '13',
#   'time': '569',
#   'goals': '2',
#   'xG': '2.525248073041439',
#   'assists': '0',
#   'xA': '0.18485304713249207',
#   'shots': '15',
#   'key_passes': '3',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Cadiz',
#   'npg': '2',
#   'npxG': '2.525248073041439',
#   'xGChain': '3.289915796369314',
#   'xGBuildup': '1.0128992181271315'},
#  {'id': '1857',
#   'player_name': 'David López',
#   'games': '8',
#   'time': '696',
#   'goals': '2',
#   'xG': '0.8909817598760128',
#   'assists': '1',
#   'xA': '0.2962450496852398',
#   'shots': '6',
#   'key_passes': '3',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Girona',
#   'npg': '2',
#   'npxG': '0.8909817598760128',
#   'xGChain': '2.362446490675211',
#   'xGBuildup': '1.997667632997036'},
#  {'id': '2057',
#   'player_name': 'Ezequiel Ponce',
#   'games': '13',
#   'time': '495',
#   'goals': '2',
#   'xG': '1.320990962907672',
#   'assists': '0',
#   'xA': '0.11252981796860695',
#   'shots': '12',
#   'key_passes': '4',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Elche',
#   'npg': '2',
#   'npxG': '1.320990962907672',
#   'xGChain': '1.649819239974022',
#   'xGBuildup': '0.64802485704422'},
#  {'id': '2104',
#   'player_name': 'Sergi Roberto',
#   'games': '9',
#   'time': '358',
#   'goals': '2',
#   'xG': '0.8242195546627045',
#   'assists': '0',
#   'xA': '0.6827157102525234',
#   'shots': '5',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Barcelona',
#   'npg': '2',
#   'npxG': '0.8242195546627045',
#   'xGChain': '5.231302302330732',
#   'xGBuildup': '3.980113919824362'},
#  {'id': '2120',
#   'player_name': 'Gerard Moreno',
#   'games': '6',
#   'time': '393',
#   'goals': '2',
#   'xG': '3.589590683579445',
#   'assists': '0',
#   'xA': '0.17361393570899963',
#   'shots': '14',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Villarreal',
#   'npg': '2',
#   'npxG': '3.589590683579445',
#   'xGChain': '3.516311928629875',
#   'xGBuildup': '0.624582389369607'},
#  {'id': '2253',
#   'player_name': 'Lucas Vázquez',
#   'games': '8',
#   'time': '365',
#   'goals': '2',
#   'xG': '0.9076640233397484',
#   'assists': '0',
#   'xA': '0.4109304342418909',
#   'shots': '7',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Real Madrid',
#   'npg': '2',
#   'npxG': '0.9076640233397484',
#   'xGChain': '2.894742188975215',
#   'xGBuildup': '1.6893692817538977'},
#  {'id': '2303',
#   'player_name': 'Samu Castillejo',
#   'games': '10',
#   'time': '628',
#   'goals': '2',
#   'xG': '1.695260938256979',
#   'assists': '0',
#   'xA': '0.6091488488018513',
#   'shots': '19',
#   'key_passes': '12',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Valencia',
#   'npg': '2',
#   'npxG': '1.695260938256979',
#   'xGChain': '3.257968880236149',
#   'xGBuildup': '1.4481606781482697'},
#  {'id': '2304',
#   'player_name': 'Leo Baptistao',
#   'games': '11',
#   'time': '574',
#   'goals': '2',
#   'xG': '1.289896572008729',
#   'assists': '1',
#   'xA': '0.7901149392127991',
#   'shots': '15',
#   'key_passes': '7',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Almeria',
#   'npg': '2',
#   'npxG': '1.289896572008729',
#   'xGChain': '2.2044134847819805',
#   'xGBuildup': '0.4660360123962164'},
#  {'id': '2356',
#   'player_name': 'Roque Mesa',
#   'games': '12',
#   'time': '886',
#   'goals': '2',
#   'xG': '0.8348343623802066',
#   'assists': '1',
#   'xA': '0.7135781208053231',
#   'shots': '14',
#   'key_passes': '12',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Valladolid',
#   'npg': '2',
#   'npxG': '0.8348343623802066',
#   'xGChain': '4.233002915047109',
#   'xGBuildup': '2.9694819301366806'},
#  {'id': '2589',
#   'player_name': 'Rafa Mir',
#   'games': '9',
#   'time': '573',
#   'goals': '2',
#   'xG': '3.2781151570379734',
#   'assists': '0',
#   'xA': '0.5903573036193848',
#   'shots': '25',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Sevilla',
#   'npg': '2',
#   'npxG': '3.2781151570379734',
#   'xGChain': '3.7774767354130745',
#   'xGBuildup': '0.058202821761369705'},
#  {'id': '2621',
#   'player_name': 'Sergi Darder',
#   'games': '14',
#   'time': '1247',
#   'goals': '2',
#   'xG': '1.0586261739954352',
#   'assists': '1',
#   'xA': '3.674416571855545',
#   'shots': '18',
#   'key_passes': '32',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Espanyol',
#   'npg': '2',
#   'npxG': '1.0586261739954352',
#   'xGChain': '5.156957682222128',
#   'xGBuildup': '2.944945774972439'},
#  {'id': '3208',
#   'player_name': 'Óscar Trejo',
#   'games': '12',
#   'time': '876',
#   'goals': '2',
#   'xG': '2.4238547813147306',
#   'assists': '2',
#   'xA': '1.7800271548330784',
#   'shots': '8',
#   'key_passes': '18',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '1',
#   'npxG': '0.9372995365411043',
#   'xGChain': '3.280561786144972',
#   'xGBuildup': '1.2996142888441682'},
#  {'id': '4177',
#   'player_name': 'Álex Fernández',
#   'games': '12',
#   'time': '693',
#   'goals': '2',
#   'xG': '1.1515888385474682',
#   'assists': '0',
#   'xA': '0.3933244124054909',
#   'shots': '9',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Cadiz',
#   'npg': '2',
#   'npxG': '1.1515888385474682',
#   'xGChain': '2.325141441076994',
#   'xGBuildup': '1.2028632760047913'},
#  {'id': '5058',
#   'player_name': 'Carles Aleñá',
#   'games': '13',
#   'time': '1049',
#   'goals': '2',
#   'xG': '0.7398644061759114',
#   'assists': '2',
#   'xA': '0.3662830702960491',
#   'shots': '13',
#   'key_passes': '7',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Getafe',
#   'npg': '2',
#   'npxG': '0.7398644061759114',
#   'xGChain': '2.3252401165664196',
#   'xGBuildup': '1.363978324458003'},
#  {'id': '5074',
#   'player_name': 'Kike García',
#   'games': '14',
#   'time': '398',
#   'goals': '2',
#   'xG': '2.5641678757965565',
#   'assists': '0',
#   'xA': '1.028941661119461',
#   'shots': '19',
#   'key_passes': '6',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Osasuna',
#   'npg': '1',
#   'npxG': '1.8208902440965176',
#   'xGChain': '2.490579891949892',
#   'xGBuildup': '0.2364015206694603'},
#  {'id': '5077',
#   'player_name': 'Mikel Vesga',
#   'games': '13',
#   'time': '916',
#   'goals': '2',
#   'xG': '1.2917504580691457',
#   'assists': '2',
#   'xA': '0.7759853843599558',
#   'shots': '12',
#   'key_passes': '13',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Athletic Club',
#   'npg': '1',
#   'npxG': '0.5484728487208486',
#   'xGChain': '4.429234340786934',
#   'xGBuildup': '3.6518563702702522'},
#  {'id': '5081',
#   'player_name': 'Edu Expósito',
#   'games': '13',
#   'time': '807',
#   'goals': '2',
#   'xG': '0.3253366118296981',
#   'assists': '2',
#   'xA': '1.5057448204606771',
#   'shots': '11',
#   'key_passes': '14',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Espanyol',
#   'npg': '2',
#   'npxG': '0.3253366118296981',
#   'xGChain': '2.652913946658373',
#   'xGBuildup': '1.8143852949142456'},
#  {'id': '5666',
#   'player_name': 'Mouctar Diakhaby',
#   'games': '10',
#   'time': '798',
#   'goals': '2',
#   'xG': '1.3666883800178766',
#   'assists': '0',
#   'xA': '0.07261011004447937',
#   'shots': '4',
#   'key_passes': '2',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'D',
#   'team_title': 'Valencia',
#   'npg': '2',
#   'npxG': '1.3666883800178766',
#   'xGChain': '2.184694157913327',
#   'xGBuildup': '2.1120840404182673'},
#  {'id': '6441',
#   'player_name': 'Ferrán Torres',
#   'games': '13',
#   'time': '558',
#   'goals': '2',
#   'xG': '4.54660976678133',
#   'assists': '0',
#   'xA': '2.146957367658615',
#   'shots': '27',
#   'key_passes': '7',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Barcelona',
#   'npg': '2',
#   'npxG': '4.54660976678133',
#   'xGChain': '8.5999291613698',
#   'xGBuildup': '3.407724417746067'},
#  {'id': '6570',
#   'player_name': 'Óscar Rodríguez',
#   'games': '13',
#   'time': '1011',
#   'goals': '2',
#   'xG': '2.584481129422784',
#   'assists': '0',
#   'xA': '0.7620820812880993',
#   'shots': '26',
#   'key_passes': '14',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Celta Vigo',
#   'npg': '2',
#   'npxG': '2.584481129422784',
#   'xGChain': '4.136346587911248',
#   'xGBuildup': '2.095335379242897'},
#  {'id': '6926',
#   'player_name': 'William Carvalho',
#   'games': '13',
#   'time': '944',
#   'goals': '2',
#   'xG': '2.167683430016041',
#   'assists': '0',
#   'xA': '0.21696944534778595',
#   'shots': '12',
#   'key_passes': '4',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Betis',
#   'npg': '2',
#   'npxG': '2.167683430016041',
#   'xGChain': '5.129829749464989',
#   'xGBuildup': '3.556409239768982'},
#  {'id': '6963',
#   'player_name': 'Justin Kluivert',
#   'games': '10',
#   'time': '522',
#   'goals': '2',
#   'xG': '1.8140801787376404',
#   'assists': '0',
#   'xA': '1.563018087297678',
#   'shots': '12',
#   'key_passes': '11',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Valencia',
#   'npg': '2',
#   'npxG': '1.8140801787376404',
#   'xGChain': '3.772823244333267',
#   'xGBuildup': '0.9795265942811966'},
#  {'id': '7313',
#   'player_name': 'Lee Kang-In',
#   'games': '14',
#   'time': '1110',
#   'goals': '2',
#   'xG': '1.0301530826836824',
#   'assists': '3',
#   'xA': '3.102024246007204',
#   'shots': '20',
#   'key_passes': '22',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Mallorca',
#   'npg': '2',
#   'npxG': '1.0301530826836824',
#   'xGChain': '4.14750486984849',
#   'xGBuildup': '1.615856945514679'},
#  {'id': '7528',
#   'player_name': 'Sergio Camello',
#   'games': '14',
#   'time': '959',
#   'goals': '2',
#   'xG': '2.704522877931595',
#   'assists': '2',
#   'xA': '1.4441997893154621',
#   'shots': '29',
#   'key_passes': '13',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '2',
#   'npxG': '2.704522877931595',
#   'xGChain': '4.033390576019883',
#   'xGBuildup': '0.8645416367799044'},
#  {'id': '7529',
#   'player_name': 'Iván Martín',
#   'games': '2',
#   'time': '102',
#   'goals': '2',
#   'xG': '0.5523902624845505',
#   'assists': '0',
#   'xA': '0.15123790502548218',
#   'shots': '2',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Girona',
#   'npg': '2',
#   'npxG': '0.5523902624845505',
#   'xGChain': '1.713707610964775',
#   'xGBuildup': '1.0100793838500977'},
#  {'id': '7781',
#   'player_name': 'Frenkie de Jong',
#   'games': '13',
#   'time': '889',
#   'goals': '2',
#   'xG': '2.0921022333204746',
#   'assists': '1',
#   'xA': '1.3445754200220108',
#   'shots': '13',
#   'key_passes': '18',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Barcelona',
#   'npg': '2',
#   'npxG': '2.0921022333204746',
#   'xGChain': '9.870868012309074',
#   'xGBuildup': '7.318945698440075'},
#  {'id': '7888',
#   'player_name': 'Nemanja Gudelj',
#   'games': '12',
#   'time': '1038',
#   'goals': '2',
#   'xG': '1.1117455707862973',
#   'assists': '0',
#   'xA': '0.041590881533920765',
#   'shots': '18',
#   'key_passes': '2',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Sevilla',
#   'npg': '2',
#   'npxG': '1.1117455707862973',
#   'xGChain': '2.0062498580664396',
#   'xGBuildup': '1.2061764169484377'},
#  {'id': '7892',
#   'player_name': 'João Félix',
#   'games': '12',
#   'time': '504',
#   'goals': '2',
#   'xG': '2.547314092516899',
#   'assists': '3',
#   'xA': '1.3935227505862713',
#   'shots': '19',
#   'key_passes': '8',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Atletico Madrid',
#   'npg': '2',
#   'npxG': '2.547314092516899',
#   'xGChain': '4.517606556415558',
#   'xGBuildup': '0.8360769776627421'},
#  {'id': '8001',
#   'player_name': 'Takefusa Kubo',
#   'games': '12',
#   'time': '872',
#   'goals': '2',
#   'xG': '2.342126429080963',
#   'assists': '2',
#   'xA': '2.778594948351383',
#   'shots': '21',
#   'key_passes': '12',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Sociedad',
#   'npg': '2',
#   'npxG': '2.342126429080963',
#   'xGChain': '5.982043202966452',
#   'xGBuildup': '1.8429400399327278'},
#  {'id': '8026',
#   'player_name': 'Raphinha',
#   'games': '13',
#   'time': '567',
#   'goals': '2',
#   'xG': '3.5556396655738354',
#   'assists': '2',
#   'xA': '3.339534003287554',
#   'shots': '26',
#   'key_passes': '20',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Barcelona',
#   'npg': '2',
#   'npxG': '3.5556396655738354',
#   'xGChain': '9.546970576047897',
#   'xGBuildup': '5.418120205402374'},
#  {'id': '8066',
#   'player_name': 'Arnaut Danjuma Groeneveld',
#   'games': '9',
#   'time': '474',
#   'goals': '2',
#   'xG': '2.527806155383587',
#   'assists': '0',
#   'xA': '0.20873001962900162',
#   'shots': '8',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Villarreal',
#   'npg': '1',
#   'npxG': '1.7845286056399345',
#   'xGChain': '2.224414683878422',
#   'xGBuildup': '0.23115605860948563'},
#  {'id': '8424',
#   'player_name': 'Aimar Oroz',
#   'games': '12',
#   'time': '787',
#   'goals': '2',
#   'xG': '2.3451212868094444',
#   'assists': '1',
#   'xA': '0.5040801949799061',
#   'shots': '9',
#   'key_passes': '11',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Osasuna',
#   'npg': '1',
#   'npxG': '1.6018436774611473',
#   'xGChain': '3.2092576306313276',
#   'xGBuildup': '1.2963644284754992'},
#  {'id': '9809',
#   'player_name': 'José Ángel Carmona',
#   'games': '9',
#   'time': '438',
#   'goals': '2',
#   'xG': '1.3386146984994411',
#   'assists': '1',
#   'xA': '0.36233579367399216',
#   'shots': '5',
#   'key_passes': '2',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Sevilla',
#   'npg': '2',
#   'npxG': '1.3386146984994411',
#   'xGChain': '1.2217554319649935',
#   'xGBuildup': '0.179021080955863'},
#  {'id': '10048',
#   'player_name': 'Nicolas Jackson',
#   'games': '13',
#   'time': '786',
#   'goals': '2',
#   'xG': '2.6449340730905533',
#   'assists': '2',
#   'xA': '1.9197969809174538',
#   'shots': '16',
#   'key_passes': '8',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Villarreal',
#   'npg': '2',
#   'npxG': '2.6449340730905533',
#   'xGChain': '5.984894726425409',
#   'xGBuildup': '1.6877040304243565'},
#  {'id': '10412',
#   'player_name': 'Gastón Álvarez',
#   'games': '7',
#   'time': '417',
#   'goals': '2',
#   'xG': '0.9497556462883949',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'D S',
#   'team_title': 'Getafe',
#   'npg': '2',
#   'npxG': '0.9497556462883949',
#   'xGChain': '0.24348384141921997',
#   'xGBuildup': '0.24348384141921997'},
#  {'id': '10943',
#   'player_name': 'Samuel Lino',
#   'games': '14',
#   'time': '1223',
#   'goals': '2',
#   'xG': '3.0809889547526836',
#   'assists': '0',
#   'xA': '0.9702408872544765',
#   'shots': '38',
#   'key_passes': '14',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Valencia',
#   'npg': '2',
#   'npxG': '3.0809889547526836',
#   'xGChain': '6.584159582853317',
#   'xGBuildup': '2.9518659822642803'},
#  {'id': '10949',
#   'player_name': 'Arnau Martinez',
#   'games': '11',
#   'time': '820',
#   'goals': '2',
#   'xG': '1.0564614720642567',
#   'assists': '1',
#   'xA': '1.4257287811487913',
#   'shots': '12',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Girona',
#   'npg': '2',
#   'npxG': '1.0564614720642567',
#   'xGChain': '3.3545515406876802',
#   'xGBuildup': '2.065273445099592'},
#  {'id': '10975',
#   'player_name': 'Largie Ramazani',
#   'games': '14',
#   'time': '804',
#   'goals': '2',
#   'xG': '2.433174902573228',
#   'assists': '0',
#   'xA': '0.4805016051977873',
#   'shots': '23',
#   'key_passes': '7',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Almeria',
#   'npg': '2',
#   'npxG': '2.433174902573228',
#   'xGChain': '3.3791780695319176',
#   'xGBuildup': '0.7171962289139628'},
#  {'id': '11057',
#   'player_name': 'André Almeida',
#   'games': '11',
#   'time': '711',
#   'goals': '2',
#   'xG': '0.5375603251159191',
#   'assists': '2',
#   'xA': '1.482417456805706',
#   'shots': '8',
#   'key_passes': '10',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Valencia',
#   'npg': '2',
#   'npxG': '0.5375603251159191',
#   'xGChain': '3.3119568414986134',
#   'xGBuildup': '2.4155451729893684'},
#  {'id': '391',
#   'player_name': 'David Alaba',
#   'games': '14',
#   'time': '1168',
#   'goals': '1',
#   'xG': '0.78852903470397',
#   'assists': '3',
#   'xA': '0.6298664715141058',
#   'shots': '9',
#   'key_passes': '12',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Real Madrid',
#   'npg': '1',
#   'npxG': '0.78852903470397',
#   'xGChain': '5.459671285003424',
#   'xGBuildup': '5.026944939047098'},
#  {'id': '493',
#   'player_name': 'Gabriel',
#   'games': '10',
#   'time': '571',
#   'goals': '1',
#   'xG': '1.102429386228323',
#   'assists': '0',
#   'xA': '0.2789023295044899',
#   'shots': '11',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Valencia',
#   'npg': '1',
#   'npxG': '1.102429386228323',
#   'xGChain': '1.5266379192471504',
#   'xGBuildup': '1.3888092786073685'},
#  {'id': '497',
#   'player_name': 'Francis Coquelin',
#   'games': '11',
#   'time': '523',
#   'goals': '1',
#   'xG': '0.2977447882294655',
#   'assists': '0',
#   'xA': '0.7958357483148575',
#   'shots': '4',
#   'key_passes': '4',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Villarreal',
#   'npg': '1',
#   'npxG': '0.2977447882294655',
#   'xGChain': '2.067836783826351',
#   'xGBuildup': '1.2694800067692995'},
#  {'id': '555',
#   'player_name': 'Memphis Depay',
#   'games': '2',
#   'time': '124',
#   'goals': '1',
#   'xG': '1.0523141622543335',
#   'assists': '0',
#   'xA': '0.09116024523973465',
#   'shots': '6',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Barcelona',
#   'npg': '1',
#   'npxG': '1.0523141622543335',
#   'xGChain': '1.6564082652330399',
#   'xGBuildup': '0.710014596581459'},
#  {'id': '842',
#   'player_name': 'Oriol Romeu',
#   'games': '11',
#   'time': '990',
#   'goals': '1',
#   'xG': '1.011229407042265',
#   'assists': '0',
#   'xA': '0.1491924598813057',
#   'shots': '11',
#   'key_passes': '6',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Girona',
#   'npg': '1',
#   'npxG': '1.011229407042265',
#   'xGChain': '4.523596212267876',
#   'xGBuildup': '4.061185419559479'},
#  {'id': '1003',
#   'player_name': 'Pablo Maffeo',
#   'games': '12',
#   'time': '1017',
#   'goals': '1',
#   'xG': '0.6002653203904629',
#   'assists': '0',
#   'xA': '0.6886067688465118',
#   'shots': '5',
#   'key_passes': '9',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'D',
#   'team_title': 'Mallorca',
#   'npg': '1',
#   'npxG': '0.6002653203904629',
#   'xGChain': '1.8343895189464092',
#   'xGBuildup': '0.7164674587547779'},
#  {'id': '1145',
#   'player_name': 'Rodrigo de Paul',
#   'games': '12',
#   'time': '688',
#   'goals': '1',
#   'xG': '0.28237111680209637',
#   'assists': '1',
#   'xA': '1.4538243524730206',
#   'shots': '8',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '1',
#   'npxG': '0.28237111680209637',
#   'xGChain': '2.928166786208749',
#   'xGBuildup': '1.8145594084635377'},
#  {'id': '1189',
#   'player_name': 'Lucas Boyé',
#   'games': '12',
#   'time': '750',
#   'goals': '1',
#   'xG': '1.6341856364160776',
#   'assists': '2',
#   'xA': '0.5414023660123348',
#   'shots': '10',
#   'key_passes': '7',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Elche',
#   'npg': '1',
#   'npxG': '0.8909080270677805',
#   'xGChain': '1.8473804593086243',
#   'xGBuildup': '1.0769783109426498'},
#  {'id': '1235',
#   'player_name': 'Ante Budimir',
#   'games': '11',
#   'time': '564',
#   'goals': '1',
#   'xG': '2.4188075065612793',
#   'assists': '0',
#   'xA': '0.5741747682914138',
#   'shots': '19',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Osasuna',
#   'npg': '1',
#   'npxG': '2.4188075065612793',
#   'xGChain': '3.047846286557615',
#   'xGBuildup': '0.9238288700580597'},
#  {'id': '1461',
#   'player_name': 'Pol Lirola',
#   'games': '8',
#   'time': '560',
#   'goals': '1',
#   'xG': '0.41901910305023193',
#   'assists': '0',
#   'xA': '0.6457754466682673',
#   'shots': '1',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Elche',
#   'npg': '1',
#   'npxG': '0.41901910305023193',
#   'xGChain': '1.5808118656277657',
#   'xGBuildup': '0.543937929905951'},
#  {'id': '1715',
#   'player_name': 'Álvaro Negredo',
#   'games': '10',
#   'time': '411',
#   'goals': '1',
#   'xG': '0.866029279306531',
#   'assists': '1',
#   'xA': '0.8684976380318403',
#   'shots': '6',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Cadiz',
#   'npg': '1',
#   'npxG': '0.866029279306531',
#   'xGChain': '1.8315956499427557',
#   'xGBuildup': '0.14297979697585106'},
#  {'id': '1822',
#   'player_name': 'Antonio Rüdiger',
#   'games': '12',
#   'time': '676',
#   'goals': '1',
#   'xG': '1.0258768433704972',
#   'assists': '0',
#   'xA': '0.1438727229833603',
#   'shots': '7',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Real Madrid',
#   'npg': '1',
#   'npxG': '1.0258768433704972',
#   'xGChain': '4.178850911557674',
#   'xGBuildup': '4.091673441231251'},
#  {'id': '2106',
#   'player_name': 'Munir',
#   'games': '8',
#   'time': '204',
#   'goals': '1',
#   'xG': '0.35704242810606956',
#   'assists': '0',
#   'xA': '0.0756215825676918',
#   'shots': '7',
#   'key_passes': '1',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Getafe',
#   'npg': '1',
#   'npxG': '0.35704242810606956',
#   'xGChain': '0.5721103250980377',
#   'xGBuildup': '0.3033270761370659'},
#  {'id': '2117',
#   'player_name': 'Marco Asensio',
#   'games': '9',
#   'time': '162',
#   'goals': '1',
#   'xG': '0.866184463724494',
#   'assists': '2',
#   'xA': '1.2514893785119057',
#   'shots': '8',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Real Madrid',
#   'npg': '1',
#   'npxG': '0.866184463724494',
#   'xGChain': '2.619277097284794',
#   'xGBuildup': '1.0499212313443422'},
#  {'id': '2166',
#   'player_name': 'Adrián Embarba',
#   'games': '10',
#   'time': '465',
#   'goals': '1',
#   'xG': '0.5900236815214157',
#   'assists': '3',
#   'xA': '1.138665346428752',
#   'shots': '13',
#   'key_passes': '11',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Almeria,Espanyol',
#   'npg': '1',
#   'npxG': '0.5900236815214157',
#   'xGChain': '1.0242182612419128',
#   'xGBuildup': '0.09757482446730137'},
#  {'id': '2183',
#   'player_name': 'Rubén García',
#   'games': '11',
#   'time': '421',
#   'goals': '1',
#   'xG': '1.460622601211071',
#   'assists': '2',
#   'xA': '0.9379025585949421',
#   'shots': '11',
#   'key_passes': '12',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Osasuna',
#   'npg': '1',
#   'npxG': '1.460622601211071',
#   'xGChain': '3.1799810603260994',
#   'xGBuildup': '1.5140674579888582'},
#  {'id': '2186',
#   'player_name': 'Morales',
#   'games': '13',
#   'time': '401',
#   'goals': '1',
#   'xG': '2.103632688522339',
#   'assists': '0',
#   'xA': '0.40806204080581665',
#   'shots': '13',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Villarreal',
#   'npg': '1',
#   'npxG': '2.103632688522339',
#   'xGChain': '2.8705688528716564',
#   'xGBuildup': '0.3588742110878229'},
#  {'id': '2194',
#   'player_name': 'Damián Suárez',
#   'games': '7',
#   'time': '549',
#   'goals': '1',
#   'xG': '0.07324239797890186',
#   'assists': '0',
#   'xA': '0.6154742371290922',
#   'shots': '2',
#   'key_passes': '10',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Getafe',
#   'npg': '1',
#   'npxG': '0.07324239797890186',
#   'xGChain': '1.7391183525323868',
#   'xGBuildup': '1.526909925043583'},
#  {'id': '2198',
#   'player_name': 'Moi Gómez',
#   'games': '14',
#   'time': '1161',
#   'goals': '1',
#   'xG': '0.9993670145049691',
#   'assists': '1',
#   'xA': '3.0484533607959747',
#   'shots': '10',
#   'key_passes': '30',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Osasuna',
#   'npg': '1',
#   'npxG': '0.9993670145049691',
#   'xGChain': '5.068029575049877',
#   'xGBuildup': '3.5518706142902374'},
#  {'id': '2232',
#   'player_name': 'Asier Illarramendi',
#   'games': '6',
#   'time': '156',
#   'goals': '1',
#   'xG': '0.05779401585459709',
#   'assists': '0',
#   'xA': '0.03969851415604353',
#   'shots': '2',
#   'key_passes': '2',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Sociedad',
#   'npg': '1',
#   'npxG': '0.05779401585459709',
#   'xGChain': '1.3276251554489136',
#   'xGBuildup': '1.2390030175447464'},
#  {'id': '2252',
#   'player_name': 'Borja Mayoral',
#   'games': '14',
#   'time': '1139',
#   'goals': '1',
#   'xG': '2.6128722112625837',
#   'assists': '0',
#   'xA': '1.0086318589746952',
#   'shots': '17',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Getafe',
#   'npg': '1',
#   'npxG': '1.8695946019142866',
#   'xGChain': '3.3681100606918335',
#   'xGBuildup': '0.5897827036678791'},
#  {'id': '2272',
#   'player_name': 'Yannick Carrasco',
#   'games': '13',
#   'time': '749',
#   'goals': '1',
#   'xG': '1.6930473074316978',
#   'assists': '0',
#   'xA': '1.7273127045482397',
#   'shots': '21',
#   'key_passes': '18',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '1',
#   'npxG': '1.6930473074316978',
#   'xGChain': '4.648741219192743',
#   'xGBuildup': '2.1224674647673965'},
#  {'id': '2288',
#   'player_name': 'Theo Bongonda',
#   'games': '9',
#   'time': '457',
#   'goals': '1',
#   'xG': '0.3200284205377102',
#   'assists': '0',
#   'xA': '0.09227005206048489',
#   'shots': '7',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Cadiz',
#   'npg': '1',
#   'npxG': '0.3200284205377102',
#   'xGChain': '0.8223187830299139',
#   'xGBuildup': '0.5096052717417479'},
#  {'id': '2369',
#   'player_name': 'Toni Kroos',
#   'games': '11',
#   'time': '873',
#   'goals': '1',
#   'xG': '0.4434221237897873',
#   'assists': '2',
#   'xA': '2.344430722296238',
#   'shots': '12',
#   'key_passes': '20',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Real Madrid',
#   'npg': '1',
#   'npxG': '0.4434221237897873',
#   'xGChain': '6.756074085831642',
#   'xGBuildup': '6.490098461508751'},
#  {'id': '2400',
#   'player_name': 'Raúl García',
#   'games': '13',
#   'time': '319',
#   'goals': '1',
#   'xG': '1.7405313979834318',
#   'assists': '1',
#   'xA': '0.5365939885377884',
#   'shots': '23',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Athletic Club',
#   'npg': '1',
#   'npxG': '1.7405313979834318',
#   'xGChain': '2.817435674369335',
#   'xGBuildup': '0.8257166482508183'},
#  {'id': '2417',
#   'player_name': 'Igor Zubeldia',
#   'games': '10',
#   'time': '716',
#   'goals': '1',
#   'xG': '0.6629189178347588',
#   'assists': '0',
#   'xA': '0.15800344944000244',
#   'shots': '4',
#   'key_passes': '1',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Real Sociedad',
#   'npg': '1',
#   'npxG': '0.6629189178347588',
#   'xGChain': '2.5147854797542095',
#   'xGBuildup': '2.3812236972153187'},
#  {'id': '2478',
#   'player_name': 'Carlos Soler',
#   'games': '3',
#   'time': '247',
#   'goals': '1',
#   'xG': '0.9192522391676903',
#   'assists': '0',
#   'xA': '0.19721846096217632',
#   'shots': '5',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Valencia',
#   'npg': '0',
#   'npxG': '0.17597462981939316',
#   'xGChain': '0.43632021360099316',
#   'xGBuildup': '0.25645874440670013'},
#  {'id': '2479',
#   'player_name': 'Toni Lato',
#   'games': '9',
#   'time': '255',
#   'goals': '1',
#   'xG': '0.24468017742037773',
#   'assists': '0',
#   'xA': '0.6038521509617567',
#   'shots': '5',
#   'key_passes': '9',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Valencia',
#   'npg': '1',
#   'npxG': '0.24468017742037773',
#   'xGChain': '1.638350147753954',
#   'xGBuildup': '1.234533078968525'},
#  {'id': '2518',
#   'player_name': 'Marcos Llorente',
#   'games': '8',
#   'time': '669',
#   'goals': '1',
#   'xG': '0.3831279966980219',
#   'assists': '0',
#   'xA': '1.2335461489856243',
#   'shots': '8',
#   'key_passes': '9',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Atletico Madrid',
#   'npg': '1',
#   'npxG': '0.3831279966980219',
#   'xGChain': '2.3114530332386494',
#   'xGBuildup': '1.2337805703282356'},
#  {'id': '2532',
#   'player_name': 'Amath Diedhiou',
#   'games': '7',
#   'time': '225',
#   'goals': '1',
#   'xG': '0.7675153575837612',
#   'assists': '0',
#   'xA': '0.4596441984176636',
#   'shots': '7',
# ...
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Espanyol',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10883',
#   'player_name': 'Gonzalo Plata',
#   'games': '10',
#   'time': '597',
#   'goals': '0',
#   'xG': '1.755470567382872',
#   'assists': '2',
#   'xA': '1.0454164613038301',
#   'shots': '11',
#   'key_passes': '11',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Valladolid',
#   'npg': '0',
#   'npxG': '1.755470567382872',
#   'xGChain': '4.317912422120571',
#   'xGBuildup': '1.750192228704691'},
#  {'id': '10884',
#   'player_name': 'Álvaro Aguado',
#   'games': '13',
#   'time': '740',
#   'goals': '0',
#   'xG': '0.23303111270070076',
#   'assists': '2',
#   'xA': '0.927290964871645',
#   'shots': '6',
#   'key_passes': '15',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Valladolid',
#   'npg': '0',
#   'npxG': '0.23303111270070076',
#   'xGChain': '3.012828888371587',
#   'xGBuildup': '2.430717115290463'},
#  {'id': '10885',
#   'player_name': 'Sekou Gassama',
#   'games': '1',
#   'time': '32',
#   'goals': '0',
#   'xG': '0.48198020458221436',
#   'assists': '0',
#   'xA': '0.029002826660871506',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Real Valladolid',
#   'npg': '0',
#   'npxG': '0.48198020458221436',
#   'xGChain': '0.5363950729370117',
#   'xGBuildup': '0.025412002578377724'},
#  {'id': '10886',
#   'player_name': 'Iván Fresneda',
#   'games': '6',
#   'time': '466',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.9931400045752525',
#   'shots': '0',
#   'key_passes': '9',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Real Valladolid',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.8245502263307571',
#   'xGBuildup': '0.8314101919531822'},
#  {'id': '10889',
#   'player_name': 'Roberto Arroyo',
#   'games': '1',
#   'time': '10',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Real Valladolid',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10916',
#   'player_name': 'Pablo Muñoz',
#   'games': '2',
#   'time': '10',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10928',
#   'player_name': 'Awer Mabil',
#   'games': '5',
#   'time': '155',
#   'goals': '0',
#   'xG': '0.3261428661644459',
#   'assists': '0',
#   'xA': '0.013875761069357395',
#   'shots': '3',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Cadiz',
#   'npg': '0',
#   'npxG': '0.3261428661644459',
#   'xGChain': '0.4220724068582058',
#   'xGBuildup': '0.36816877871751785'},
#  {'id': '10944',
#   'player_name': 'Fran Pérez',
#   'games': '2',
#   'time': '12',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Valencia',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.10019449889659882',
#   'xGBuildup': '0.10019449889659882'},
#  {'id': '10945',
#   'player_name': 'Santiago Bueno',
#   'games': '14',
#   'time': '1260',
#   'goals': '0',
#   'xG': '0.4630641546100378',
#   'assists': '1',
#   'xA': '0.7314962800592184',
#   'shots': '8',
#   'key_passes': '3',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Girona',
#   'npg': '0',
#   'npxG': '0.4630641546100378',
#   'xGChain': '2.8048839289695024',
#   'xGBuildup': '2.7640785593539476'},
#  {'id': '10946',
#   'player_name': 'Yan Couto',
#   'games': '10',
#   'time': '501',
#   'goals': '0',
#   'xG': '0.0591949000954628',
#   'assists': '0',
#   'xA': '0.8477099910378456',
#   'shots': '2',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Girona',
#   'npg': '0',
#   'npxG': '0.0591949000954628',
#   'xGChain': '1.4957851823419333',
#   'xGBuildup': '0.64807522110641'},
#  {'id': '10947',
#   'player_name': 'Ramón Terrats',
#   'games': '6',
#   'time': '140',
#   'goals': '0',
#   'xG': '0.15384344197809696',
#   'assists': '0',
#   'xA': '0.02826075069606304',
#   'shots': '3',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Girona',
#   'npg': '0',
#   'npxG': '0.15384344197809696',
#   'xGChain': '0.24877983517944813',
#   'xGBuildup': '0.06667564064264297'},
#  {'id': '10950',
#   'player_name': 'Oscar Ureña',
#   'games': '3',
#   'time': '95',
#   'goals': '0',
#   'xG': '0.06667564064264297',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Girona',
#   'npg': '0',
#   'npxG': '0.06667564064264297',
#   'xGChain': '0.06667564064264297',
#   'xGBuildup': '0'},
#  {'id': '10952',
#   'player_name': 'Joel Roca',
#   'games': '2',
#   'time': '9',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Girona',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10969',
#   'player_name': 'Fernando Martínez',
#   'games': '13',
#   'time': '1170',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Almeria',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.5494698472321033',
#   'xGBuildup': '1.5494698472321033'},
#  {'id': '10970',
#   'player_name': 'Kaiky',
#   'games': '8',
#   'time': '493',
#   'goals': '0',
#   'xG': '0.08417125791311264',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Almeria',
#   'npg': '0',
#   'npxG': '0.08417125791311264',
#   'xGChain': '1.1659394577145576',
#   'xGBuildup': '1.1659394577145576'},
#  {'id': '10974',
#   'player_name': 'Samú Costa',
#   'games': '11',
#   'time': '762',
#   'goals': '0',
#   'xG': '0.2119476506486535',
#   'assists': '0',
#   'xA': '0.18981869146227837',
#   'shots': '5',
#   'key_passes': '5',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Almeria',
#   'npg': '0',
#   'npxG': '0.2119476506486535',
#   'xGChain': '1.4834382440894842',
#   'xGBuildup': '1.4055598098784685'},
#  {'id': '10976',
#   'player_name': 'Dyego Sousa',
#   'games': '10',
#   'time': '282',
#   'goals': '0',
#   'xG': '0.3036864846944809',
#   'assists': '1',
#   'xA': '0.714352497830987',
#   'shots': '8',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Almeria',
#   'npg': '0',
#   'npxG': '0.3036864846944809',
#   'xGChain': '0.6388918943703175',
#   'xGBuildup': '0.19491485133767128'},
#  {'id': '10977',
#   'player_name': 'Arnau Puigmal',
#   'games': '7',
#   'time': '227',
#   'goals': '0',
#   'xG': '0.12569641135632992',
#   'assists': '0',
#   'xA': '0.1338274534791708',
#   'shots': '4',
#   'key_passes': '3',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Almeria',
#   'npg': '0',
#   'npxG': '0.12569641135632992',
#   'xGChain': '0.38212889805436134',
#   'xGBuildup': '0.2369963638484478'},
#  {'id': '10981',
#   'player_name': 'Malcom Adu',
#   'games': '1',
#   'time': '3',
#   'goals': '0',
#   'xG': '0.013545852154493332',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Athletic Club',
#   'npg': '0',
#   'npxG': '0.013545852154493332',
#   'xGChain': '0.03393579646945',
#   'xGBuildup': '0.020389946177601814'},
#  {'id': '10982',
#   'player_name': 'Copete',
#   'games': '12',
#   'time': '1016',
#   'goals': '0',
#   'xG': '0.6271452344954014',
#   'assists': '0',
#   'xA': '0.057833392173051834',
#   'shots': '3',
#   'key_passes': '1',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Mallorca',
#   'npg': '0',
#   'npxG': '0.6271452344954014',
#   'xGChain': '2.0792982652783394',
#   'xGBuildup': '2.0792982652783394'},
#  {'id': '10983',
#   'player_name': 'Braian Cufré',
#   'games': '3',
#   'time': '192',
#   'goals': '0',
#   'xG': '0.09920359402894974',
#   'assists': '0',
#   'xA': '0.04714071750640869',
#   'shots': '3',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Mallorca',
#   'npg': '0',
#   'npxG': '0.09920359402894974',
#   'xGChain': '0.14634431153535843',
#   'xGBuildup': '0.04714071750640869'},
#  {'id': '10987',
#   'player_name': 'Fabrizio Angileri',
#   'games': '8',
#   'time': '517',
#   'goals': '0',
#   'xG': '0.07613686472177505',
#   'assists': '0',
#   'xA': '0',
#   'shots': '3',
#   'key_passes': '0',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'D S',
#   'team_title': 'Getafe',
#   'npg': '0',
#   'npxG': '0.07613686472177505',
#   'xGChain': '0.29321236070245504',
#   'xGBuildup': '0.2427916368469596'},
#  {'id': '10988',
#   'player_name': 'Moi Parra',
#   'games': '1',
#   'time': '7',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Getafe',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10990',
#   'player_name': 'Álex Revuelta',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Getafe',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10998',
#   'player_name': 'Alejandro Alfaro',
#   'games': '1',
#   'time': '11',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Elche',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10999',
#   'player_name': 'Marcão',
#   'games': '4',
#   'time': '360',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Sevilla',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.47106445021927357',
#   'xGBuildup': '0.47106445021927357'},
#  {'id': '11025',
#   'player_name': 'Pablo Torre',
#   'games': '1',
#   'time': '8',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Barcelona',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11030',
#   'player_name': 'Luiz Henrique',
#   'games': '12',
#   'time': '754',
#   'goals': '0',
#   'xG': '1.2094398569315672',
#   'assists': '1',
#   'xA': '1.1044497229158878',
#   'shots': '16',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Betis',
#   'npg': '0',
#   'npxG': '1.2094398569315672',
#   'xGChain': '2.418615195900202',
#   'xGBuildup': '0.8069688975811005'},
#  {'id': '11042',
#   'player_name': 'Marko Milovanovic',
#   'games': '2',
#   'time': '13',
#   'goals': '0',
#   'xG': '0.05453794449567795',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Almeria',
#   'npg': '0',
#   'npxG': '0.05453794449567795',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11070',
#   'player_name': 'Jørgen Strand Larsen',
#   'games': '10',
#   'time': '712',
#   'goals': '0',
#   'xG': '1.8829363025724888',
#   'assists': '2',
#   'xA': '0.9995844606310129',
#   'shots': '16',
#   'key_passes': '4',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Celta Vigo',
#   'npg': '0',
#   'npxG': '1.8829363025724888',
#   'xGChain': '2.7226035222411156',
#   'xGBuildup': '0.697123859077692'},
#  {'id': '11071',
#   'player_name': 'Brian Ocampo',
#   'games': '10',
#   'time': '566',
#   'goals': '0',
#   'xG': '0.266035083681345',
#   'assists': '0',
#   'xA': '0.42548609897494316',
#   'shots': '5',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Cadiz',
#   'npg': '0',
#   'npxG': '0.266035083681345',
#   'xGChain': '1.1084641190245748',
#   'xGBuildup': '0.442340481095016'},
#  {'id': '11087',
#   'player_name': 'Pep Chavarría',
#   'games': '4',
#   'time': '56',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.04574272409081459',
#   'shots': '0',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.7082641068845987',
#   'xGBuildup': '0.6625214163213968'},
#  {'id': '11105',
#   'player_name': 'Abdul Mumin',
#   'games': '2',
#   'time': '99',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.014842218719422817',
#   'shots': '0',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.49356672167778015',
#   'xGBuildup': '0.47872450947761536'},
#  {'id': '11121',
#   'player_name': 'Nicolás Fernández Mercau',
#   'games': '8',
#   'time': '270',
#   'goals': '0',
#   'xG': '0.02276667021214962',
#   'assists': '0',
#   'xA': '0.3147103600203991',
#   'shots': '1',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Elche',
#   'npg': '0',
#   'npxG': '0.02276667021214962',
#   'xGChain': '0.5884503088891506',
#   'xGBuildup': '0.5285813212394714'},
#  {'id': '11147',
#   'player_name': 'Lucas Rosa',
#   'games': '5',
#   'time': '323',
#   'goals': '0',
#   'xG': '0.15239079110324383',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Real Valladolid',
#   'npg': '0',
#   'npxG': '0.15239079110324383',
#   'xGChain': '0.7845875527709723',
#   'xGBuildup': '0.6321967616677284'},
#  {'id': '11154',
#   'player_name': 'Pablo Durán',
#   'games': '3',
#   'time': '20',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Celta Vigo',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11167',
#   'player_name': 'Chadi Riad',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Barcelona',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11185',
#   'player_name': 'Pablo Marín',
#   'games': '3',
#   'time': '92',
#   'goals': '0',
#   'xG': '0.5573316775262356',
#   'assists': '0',
#   'xA': '0.14530212804675102',
#   'shots': '5',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Sociedad',
#   'npg': '0',
#   'npxG': '0.5573316775262356',
#   'xGChain': '0.8967429101467133',
#   'xGBuildup': '0.21847200393676758'},
#  {'id': '11202',
#   'player_name': 'Alberto del Moral',
#   'games': '1',
#   'time': '2',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Villarreal',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11204',
#   'player_name': 'Jon Magunacelaya',
#   'games': '2',
#   'time': '58',
#   'goals': '0',
#   'xG': '0.027830135077238083',
#   'assists': '0',
#   'xA': '0.6553639769554138',
#   'shots': '1',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Real Sociedad',
#   'npg': '0',
#   'npxG': '0.027830135077238083',
#   'xGChain': '0.6553639769554138',
#   'xGBuildup': '0'}]
