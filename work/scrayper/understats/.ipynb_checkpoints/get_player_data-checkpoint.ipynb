# %%
import glob
import json
import os
import pickle
import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import numpy as np
from lxml import html

# %%
url ='https://understat.com/player/8026'
html = requests.get(url)
soup = BeautifulSoup(html.content,'lxml')

# %%
scripts = soup.find_all('script')
strings = scripts[3].string
indexStart = strings.index("('")+2
indexEnd = strings.index("')")
json_data = strings[indexStart:indexEnd]
json_data = json_data.encode('utf8').decode('unicode_escape')

# %%
data = json.loads(json_data)
# data

# %%
player = []
playerId = []
situation = []
shotType = []
player_assisted =[]
lastAction = []
x = []
y = []
xg = []
result = []
season = []
matchId = []

for i in range(len(data)):
    for key in data[i]:
        if key=='player':
            player.append(data[i][key])
        if key=='player_id':
            playerId.append(data[i][key])
        if key=='situation':
            situation.append(data[i][key])
        if key=='shotType':
            shotType.append(data[i][key])
        if key=='X':
            x.append(data[i][key])
        if key=='Y':
            y.append(data[i][key])
        if key=='xG':
            xg.append(data[i][key])
        if key=='result':
            result.append(data[i][key])
        if key=='season':
            season.append(data[i][key])
        if key=='match_id':
            matchId.append(data[i][key])

# %%
columns = ['player', 'player_id', 'situation', 'shot_type', 'x', 'y', 'xG', 'result', 'season', 'match_id']
df_understat = pd.DataFrame([player, playerId, situation, shotType, x, y, xg, result, season, matchId], index=columns)

# %%
df_understat = df_understat.T
df_understat = df_understat.apply(pd.to_numeric,errors='ignore')
df_understat
# Out:
#        player  player_id       situation  shot_type      x      y        xG  \
# 0    Raphinha       8026        OpenPlay   LeftFoot  0.779  0.442  0.026582
# 1    Raphinha       8026        OpenPlay   LeftFoot  0.716  0.340  0.024230
# 2    Raphinha       8026  DirectFreekick   LeftFoot  0.868  0.126  0.041305
# 3    Raphinha       8026        OpenPlay  RightFoot  0.905  0.346  0.069949
# 4    Raphinha       8026        OpenPlay   LeftFoot  0.707  0.309  0.013371
# ..        ...        ...             ...        ...    ...    ...       ...
# 234  Raphinha       8026        OpenPlay  RightFoot  0.897  0.392  0.110769
# 235  Raphinha       8026        OpenPlay   LeftFoot  0.805  0.342  0.040235
# 236  Raphinha       8026        OpenPlay   LeftFoot  0.862  0.264  0.037724
# 237  Raphinha       8026        OpenPlay   LeftFoot  0.879  0.679  0.066080
# 238  Raphinha       8026        OpenPlay   LeftFoot  0.857  0.306  0.041826
#
#           result  season  match_id
# 0    MissedShots    2019     12752
# 1      SavedShot    2019     12752
# 2    MissedShots    2019     12767
# 3    MissedShots    2019     12767
# 4      SavedShot    2019     12767
# ..           ...     ...       ...
# 234  BlockedShot    2022     19103
# 235    SavedShot    2022     19103
# 236    SavedShot    2022     19103
# 237  BlockedShot    2022     19113
# 238  MissedShots    2022     19147
#
# [239 rows x 10 columns]

# %%
pitch_height = 120
pitch_width = 80
df_understat['x'] = df_understat['x'].apply(lambda x:x*pitch_height)
df_understat['y'] = df_understat['y'].apply(lambda x:x*pitch_width)

# %%
player = df_understat["player"][0]
player = player.replace(" ", "_")
df_understat.to_csv(f"/work/assets/understats/player_stats/{player}.csv")

# %%
url ='https://understat.com/team/Real_Madrid/2022'
html = requests.get(url)
soup = BeautifulSoup(html.content,'lxml')

# %%
scripts = soup.find_all('script')
strings = scripts[3].string
indexStart = strings.index("('")+2
indexEnd = strings.index("')")
json_data = strings[indexStart:indexEnd]
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)

# %%
player_ids = []
for idx, _data in enumerate(data):
    for key in _data:
        if key == "id":
            player_ids.append(_data[key])

# %%
player_ids
# Out:
# ['2370',
#  '6241',
#  '7008',
#  '8015',
#  '2250',
#  '7829',
#  '2253',
#  '2369',
#  '391',
#  '1822',
#  '2117',
#  '680',
#  '701',
#  '2247',
#  '2248',
#  '2260',
#  '2446',
#  '5110',
#  '6233',
#  '6560',
#  '7194',
#  '7359']

# %%
! python /work/scrayper/understats/get_player_data.py "Real_Madrid"
# Out:
# ['2370', '6241', '7008', '8015', '2250', '7829', '2253', '2369', '391', '1822', '2117', '680', '701', '2247', '2248', '2260', '2446', '5110', '6233', '6560', '7194', '7359']
# Karim_Benzema
# Federico_Valverde
# Vinícius_Júnior
# Rodrygo
# Luka_Modric
# Eder_Militão
# Lucas_Vázquez
# Toni_Kroos
# David_Alaba
# Antonio_Rüdiger
# Marco_Asensio
# Thibaut_Courtois
# Eden_Hazard
# Nacho
# Casemiro
# Daniel_Carvajal
# Dani_Ceballos
# Mariano
# Ferland_Mendy
# Aurelien_Tchouameni
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py", line 385, in get_loc
#     return self._range.index(new_key)
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/work/scrayper/understats/get_player_data.py", line 114, in <module>
#     get_player_data(player_ids)
#   File "/work/scrayper/understats/get_player_data.py", line 86, in get_player_data
#     player = df_understat["player"][0]
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 958, in __getitem__
#     return self._get_value(key)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 1069, in _get_value
#     loc = self.index.get_loc(label)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py", line 387, in get_loc
#     raise KeyError(key) from err
# KeyError: 0

# %%
# !chmod 764 /work/scrayper/understats/get_player_data.py

# %%
# !ls -l get_player_data.py
# Out:
# -rwxrw-r-- 1 root root 2894 Jan 29 14:16 get_player_data.py
